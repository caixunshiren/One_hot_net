# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
torch.cuda.empty_cache()

random_seed = 0
torch.manual_seed(random_seed)

# %%
n_epochs = 200
batch_size_train = 64
batch_size_test = 500

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
train_loader = torch.utils.data.DataLoader(trainset, batch_size=batch_size_train,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
test_loader = torch.utils.data.DataLoader(testset, batch_size=batch_size_test,
                                         shuffle=True, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
examples = enumerate(test_loader)
batch_idx, (example_data, example_targets) = next(examples)
print(example_data.shape)
# Out:
# torch.Size([500, 3, 32, 32])

# %%
import matplotlib.pyplot as plt
import os    
os.environ['KMP_DUPLICATE_LIB_OK']='True'
fig = plt.figure()
for i in range(6):
    plt.subplot(2,3,i+1)
    plt.tight_layout()
    plt.imshow((example_data[i]/2+0.5).permute(1,2,0))
    plt.title("Ground Truth: {}".format(classes[example_targets[i]]))
    plt.xticks([])
    plt.yticks([])

# %%
# network flowchart:
#input vector --- random initialized weights ---> hyperdimensional vecotor ---> one_hot_net l1 ---> ...ln... ---> sigmoid/softmax output
#One hot net

class One_hot_op(torch.autograd.Function):
    @staticmethod
    def forward(ctx, A, W, epsilon):
        Z = torch.matmul(W, A)
        ctx.Z = Z
        ctx.A = A
        ctx.W = W
        ctx.epsilon = epsilon
        ret = Z > epsilon
        #print(ret[1:10][1:10])
        return ret.float()

    @staticmethod
    def backward(ctx, dL_dA):
        step = ctx.Z > ctx.epsilon
        step = step.float()
        dL_dZ = dL_dA * step 
        
        dZ_dW = torch.transpose(ctx.A, 0,1)
        dZ_dW = torch.sign(dZ_dW)
        dZ_dA = torch.transpose(ctx.W, 0,1)
        dZ_dA = torch.sign(dZ_dA)
        dA = torch.matmul(dZ_dA,dL_dZ)
        dW = torch.matmul(dL_dZ,dZ_dW)
        return dA, dW, None


class One_hot_layer(nn.Module):
    def __init__(self, in_dim, out_dim, initialization_f, epsilon):
        super(One_hot_layer, self).__init__()
        self.in_dim = in_dim
        self.out_dim = out_dim
        self.epsilon = epsilon
        self.initialization_f = initialization_f
        initialized_weight = initialization_f(out_dim, in_dim)
        self.weight = nn.Parameter(initialized_weight, requires_grad = True)
        self.op = One_hot_op
        
    def __str__(self):
        return self.__class__.__name__ + ' (' \
               + str(self.in_dim) + ',' \
               + str(self.out_dim) + ')'
        
    def forward(self, A):
        #print(self.weight[:3][:3])
        return self.op.apply(A, self.weight, self.epsilon)
    

class One_hot_net(nn.Module):
    def __init__(self, in_dim, n_class, f_encoder, encoder_multiplier, f_initializer, epsilon, n_layers=2, layer_size_factor=[1, 5], dropout=[-1, 0.5]):
        super(One_hot_net, self).__init__()
        self.layers = nn.ModuleList()
        self.in_dim = in_dim
        feature_len = in_dim * encoder_multiplier
        self.feature_len = feature_len
        self.n_layers=n_layers
        self.layer_size_factor=layer_size_factor
        self.dropout=dropout
        self.epsilon = epsilon
        self.n_class = n_class
        self.f_encoder = f_encoder
        self.f_initializer = f_initializer
        for i in range(n_layers):
            if dropout[i] > 0:
                self.layers.append(nn.Dropout(dropout[i]))
            if i < n_layers - 1:
                self.layers.append(
                    One_hot_layer(int(feature_len // layer_size_factor[i]), int(feature_len // layer_size_factor[i + 1]), f_initializer, epsilon))
        self.tail = nn.Linear(int(feature_len // layer_size_factor[-1]), n_class)
        self.out = nn.LogSoftmax(dim = 1)
    
    def flatten(self, X):
        return X.view(X.shape[0], X.shape[1]*X.shape[2])
    
    def unflatten(self, X):
        return X.view(X.shape[0], int(self.in_dim**(1/2)), int(self.in_dim**(1/2)))

    def forward(self, X):
        X = self.flatten(X)
        X = torch.transpose(X, 0, 1)
        X = self.f_encoder.apply(X)
        for layer in self.layers:
            X = layer(X)
        X = torch.transpose(X, 0, 1)
        X = self.tail(X)
        return self.out(X)

class OHN_3_channels(nn.Module):
    def __init__(self, in_dim, n_class, f_encoder, encoder_multiplier, f_initializer, epsilon, n_layers=2, layer_size_factor=[1, 5], dropout=[-1, 0.5]):
        super(OHN_3_channels, self).__init__()
        self.n_class = n_class
        self.c1 = One_hot_net(in_dim, n_class, f_encoder, encoder_multiplier, f_initializer, epsilon, n_layers, layer_size_factor, dropout)
        self.c2 = One_hot_net(in_dim, n_class, f_encoder, encoder_multiplier, f_initializer, epsilon, n_layers, layer_size_factor, dropout)
        self.c3 = One_hot_net(in_dim, n_class, f_encoder, encoder_multiplier, f_initializer, epsilon, n_layers, layer_size_factor, dropout)
    def forward(self, X):
        out = torch.empty(X.shape[0],self.n_class,X.shape[1])
        
        out[:,:,0] = self.c1(X[:,0,:,:])
        out[:,:,1] = self.c2(X[:,1,:,:])
        out[:,:,2] = self.c3(X[:,2,:,:])
        return torch.mean(out, dim = 2)

# %%
#initializers and encoders
def uniform_initializer(out_dim, in_dim, cuda = True):
    tensor = torch.empty(out_dim, in_dim)
    if cuda:
        return torch.nn.init.uniform_(tensor, a=-2, b=2).cuda()
    else: 
        return torch.nn.init.uniform_(tensor, a=-2, b=2)

class simple_encoder():
    def __init__(self, out_dim, in_dim):
        self.W = uniform_initializer(out_dim, in_dim)
        
    def apply(self, X):
        #print(X.shape)
        #print(self.W.shape)
        return torch.matmul(self.W, X)
    
class simple_encoder_wthreshold():
    def __init__(self, out_dim, in_dim, epsilon, cuda = True):
        self.W = uniform_initializer(out_dim, in_dim, cuda)
        self.epsilon = epsilon
        
    def apply(self, X):
        #print(X.shape)
        #print(self.W.shape)
        return (torch.matmul(self.W, X) > self.epsilon).float()
    
class non_linear_encoder():
    def __init__(self, out_dim, in_dim, activation, cuda = True):
        self.W = uniform_initializer(out_dim, in_dim, cuda)
        self.activation = activation
        
    def apply(self, X):
        #print(X.shape)
        #print(self.W.shape)
        return self.activation((torch.matmul(self.W, X)))

# %%
parameters = {
    'in_dim': 1024,
    'n_class': 10,
    'f_encoder': simple_encoder_wthreshold(1024*10, 1024, 1e-3),
    'f_initializer': uniform_initializer,
    'encoder_multiplier': 10,
    'epsilon': 10e-3,
    'n_layers': 2,
    'layer_size_factor': [1, 1, 1],
    'dropout': [-1, -1, -1]
}

# %%
device = torch.device("cuda:0")
model1 = OHN_3_channels(parameters['in_dim'], parameters['n_class'], parameters['f_encoder'], parameters['encoder_multiplier'], 
                     parameters['f_initializer'], parameters['epsilon'], parameters['n_layers'], 
                     parameters['layer_size_factor'], parameters['dropout']).to(device)

#model1 = toy_Net().to(device)
optimizer1 = torch.optim.SGD(model1.parameters(), lr=0.01, momentum=0.5)
#optimizer1 = torch.optim.SGD([{'params': model1.layers.parameters(), 'lr': 0.01}, {'params': model1.tail.parameters(), 'lr': 0.01}], lr=0.01, momentum=0.5)

# %%
from torchsummary import summary
summary(model1, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#      One_hot_layer-1                    [-1, 2]     104,857,600
#             Linear-2                   [-1, 10]         102,410
#         LogSoftmax-3                   [-1, 10]               0
#        One_hot_net-4                   [-1, 10]               0
#      One_hot_layer-5                    [-1, 2]     104,857,600
#             Linear-6                   [-1, 10]         102,410
#         LogSoftmax-7                   [-1, 10]               0
#        One_hot_net-8                   [-1, 10]               0
#      One_hot_layer-9                    [-1, 2]     104,857,600
#            Linear-10                   [-1, 10]         102,410
#        LogSoftmax-11                   [-1, 10]               0
#       One_hot_net-12                   [-1, 10]               0
# ================================================================
# Total params: 314,880,030
# Trainable params: 314,880,030
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.00
# Params size (MB): 1201.17
# Estimated Total Size (MB): 1201.18
# ----------------------------------------------------------------

# %%
train_losses = []
train_counter = []
test_losses = []
test_counter = [i*len(train_loader.dataset) for i in range(n_epochs + 1)]

# %%
def train(epoch, model, optimizer, trainloader, log_interval = 10, device = torch.device("cuda:0")):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data = data.to(device)
        target = target.to(device)
        optimizer.zero_grad()
        output = model(data).to(device)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
            epoch, batch_idx * len(data), len(train_loader.dataset),
            100. * batch_idx / len(train_loader), loss.item()))
            train_losses.append(loss.item())
            train_counter.append(
            (batch_idx*64) + ((epoch-1)*len(train_loader.dataset)))
            #torch.save(model.state_dict(), '/results/model.pth')
            #torch.save(optimizer.state_dict(), '/results/optimizer.pth')
    return model, optimizer

# %%
def test(model, test_loader, device = torch.device("cuda:0")):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data = data.to(device)
            target = target.to(device)
            output = model(data).to(device)
            test_loss += F.nll_loss(output, target, size_average=False).item()
            pred = output.data.max(1, keepdim=True)[1]
            correct += pred.eq(target.data.view_as(pred)).sum()
    test_loss /= len(test_loader.dataset)
    test_losses.append(test_loss)
    print('\nTest set: Avg. loss: {:.4f}, Accuracy: {}/{} ({:.1f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return 100. * correct / len(test_loader.dataset)

# %%
model_name = "base_net_cifar1"
acc_max = test(model1, test_loader)
for epoch in range(1, n_epochs + 1):
    train(epoch, model1, optimizer1, train_loader)
    acc = test(model1, test_loader)
    if acc > acc_max:
        acc = acc_max
        print()
        print("--- saving model for best accuracy ---")
        #torch.save(model1.state_dict(), 'results/'+model_name+'.pth')
        #torch.save(optimizer1.state_dict(), 'results/'+model_name+'_optimizer.pth')
        print("--- saving finished ---")
        print()
# Out:
# C:\Users\caixu\anaconda3\lib\site-packages\torch\nn\_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Test set: Avg. loss: 2.3616, Accuracy: 853/10000 (8.5%)
#
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.364218
# Train Epoch: 1 [640/50000 (1%)]	Loss: 2.277864
# Train Epoch: 1 [1280/50000 (3%)]	Loss: 2.207307
# Train Epoch: 1 [1920/50000 (4%)]	Loss: 2.070902
# Train Epoch: 1 [2560/50000 (5%)]	Loss: 2.112967
# Train Epoch: 1 [3200/50000 (6%)]	Loss: 2.162812
# Train Epoch: 1 [3840/50000 (8%)]	Loss: 2.146184
# Train Epoch: 1 [4480/50000 (9%)]	Loss: 2.122503
# Train Epoch: 1 [5120/50000 (10%)]	Loss: 2.103294
# Train Epoch: 1 [5760/50000 (12%)]	Loss: 2.090761
# Train Epoch: 1 [6400/50000 (13%)]	Loss: 2.083980
# Train Epoch: 1 [7040/50000 (14%)]	Loss: 1.957010
# Train Epoch: 1 [7680/50000 (15%)]	Loss: 2.243290
# Train Epoch: 1 [8320/50000 (17%)]	Loss: 2.220514
# Train Epoch: 1 [8960/50000 (18%)]	Loss: 2.145205
# Train Epoch: 1 [9600/50000 (19%)]	Loss: 1.971522
# Train Epoch: 1 [10240/50000 (20%)]	Loss: 2.015942
# Train Epoch: 1 [10880/50000 (22%)]	Loss: 2.107666
# Train Epoch: 1 [11520/50000 (23%)]	Loss: 2.189940
# Train Epoch: 1 [12160/50000 (24%)]	Loss: 2.199381
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 2.304135
# Train Epoch: 1 [13440/50000 (27%)]	Loss: 2.216650
# Train Epoch: 1 [14080/50000 (28%)]	Loss: 1.981020
# Train Epoch: 1 [14720/50000 (29%)]	Loss: 2.153085
# Train Epoch: 1 [15360/50000 (31%)]	Loss: 2.010379
# Train Epoch: 1 [16000/50000 (32%)]	Loss: 1.934322
# Train Epoch: 1 [16640/50000 (33%)]	Loss: 2.026365
# Train Epoch: 1 [17280/50000 (35%)]	Loss: 1.906132
# Train Epoch: 1 [17920/50000 (36%)]	Loss: 2.271548
# Train Epoch: 1 [18560/50000 (37%)]	Loss: 1.955637
# Train Epoch: 1 [19200/50000 (38%)]	Loss: 2.184874
# Train Epoch: 1 [19840/50000 (40%)]	Loss: 2.089972
# Train Epoch: 1 [20480/50000 (41%)]	Loss: 2.281325
# Train Epoch: 1 [21120/50000 (42%)]	Loss: 2.220785
# Train Epoch: 1 [21760/50000 (43%)]	Loss: 2.028067
# Train Epoch: 1 [22400/50000 (45%)]	Loss: 2.139696
# Train Epoch: 1 [23040/50000 (46%)]	Loss: 2.174432
# Train Epoch: 1 [23680/50000 (47%)]	Loss: 2.031838
# Train Epoch: 1 [24320/50000 (49%)]	Loss: 2.086187
# Train Epoch: 1 [24960/50000 (50%)]	Loss: 2.118326
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 1.969241
# Train Epoch: 1 [26240/50000 (52%)]	Loss: 2.132613
# Train Epoch: 1 [26880/50000 (54%)]	Loss: 1.957451
# Train Epoch: 1 [27520/50000 (55%)]	Loss: 2.127279
# Train Epoch: 1 [28160/50000 (56%)]	Loss: 1.954060
# Train Epoch: 1 [28800/50000 (58%)]	Loss: 1.952498
# Train Epoch: 1 [29440/50000 (59%)]	Loss: 2.190791
# Train Epoch: 1 [30080/50000 (60%)]	Loss: 1.923603
# Train Epoch: 1 [30720/50000 (61%)]	Loss: 1.945601
# Train Epoch: 1 [31360/50000 (63%)]	Loss: 2.190295
# Train Epoch: 1 [32000/50000 (64%)]	Loss: 2.066141
# Train Epoch: 1 [32640/50000 (65%)]	Loss: 2.152714
# Train Epoch: 1 [33280/50000 (66%)]	Loss: 2.037805
# Train Epoch: 1 [33920/50000 (68%)]	Loss: 1.923902
# Train Epoch: 1 [34560/50000 (69%)]	Loss: 2.200623
# Train Epoch: 1 [35200/50000 (70%)]	Loss: 2.063915
# Train Epoch: 1 [35840/50000 (72%)]	Loss: 1.934488
# Train Epoch: 1 [36480/50000 (73%)]	Loss: 1.995243
# Train Epoch: 1 [37120/50000 (74%)]	Loss: 2.005543
# Train Epoch: 1 [37760/50000 (75%)]	Loss: 2.239618
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 2.116879
# Train Epoch: 1 [39040/50000 (78%)]	Loss: 1.929815
# Train Epoch: 1 [39680/50000 (79%)]	Loss: 1.940243
# Train Epoch: 1 [40320/50000 (81%)]	Loss: 1.982154
# Train Epoch: 1 [40960/50000 (82%)]	Loss: 1.976668
# Train Epoch: 1 [41600/50000 (83%)]	Loss: 2.087059
# Train Epoch: 1 [42240/50000 (84%)]	Loss: 2.200927
# Train Epoch: 1 [42880/50000 (86%)]	Loss: 2.205833
# Train Epoch: 1 [43520/50000 (87%)]	Loss: 2.252803
# Train Epoch: 1 [44160/50000 (88%)]	Loss: 2.066693
# Train Epoch: 1 [44800/50000 (90%)]	Loss: 2.096063
# Train Epoch: 1 [45440/50000 (91%)]	Loss: 2.271665
# Train Epoch: 1 [46080/50000 (92%)]	Loss: 2.083521
# Train Epoch: 1 [46720/50000 (93%)]	Loss: 2.112322
# Train Epoch: 1 [47360/50000 (95%)]	Loss: 1.998612
# Train Epoch: 1 [48000/50000 (96%)]	Loss: 1.947054
# Train Epoch: 1 [48640/50000 (97%)]	Loss: 2.280739
# Train Epoch: 1 [49280/50000 (98%)]	Loss: 2.030088
# Train Epoch: 1 [49920/50000 (100%)]	Loss: 2.155369
#
# Test set: Avg. loss: 2.2705, Accuracy: 2587/10000 (25.9%)
#
#
# --- saving model for best accuracy ---
# --- saving finished ---
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.943195
# Train Epoch: 2 [640/50000 (1%)]	Loss: 2.044865
# Train Epoch: 2 [1280/50000 (3%)]	Loss: 2.016607
# Train Epoch: 2 [1920/50000 (4%)]	Loss: 1.942821
# Train Epoch: 2 [2560/50000 (5%)]	Loss: 2.139553
# Train Epoch: 2 [3200/50000 (6%)]	Loss: 1.947187
# Train Epoch: 2 [3840/50000 (8%)]	Loss: 1.956738
# Train Epoch: 2 [4480/50000 (9%)]	Loss: 1.982120
# Train Epoch: 2 [5120/50000 (10%)]	Loss: 2.027314
# Train Epoch: 2 [5760/50000 (12%)]	Loss: 1.649148
# Train Epoch: 2 [6400/50000 (13%)]	Loss: 1.863224
# Train Epoch: 2 [7040/50000 (14%)]	Loss: 1.647664
# Train Epoch: 2 [7680/50000 (15%)]	Loss: 1.919045
# Train Epoch: 2 [8320/50000 (17%)]	Loss: 1.841831
# Train Epoch: 2 [8960/50000 (18%)]	Loss: 1.731592
# Train Epoch: 2 [9600/50000 (19%)]	Loss: 1.950574
# Train Epoch: 2 [10240/50000 (20%)]	Loss: 2.060534
# Train Epoch: 2 [10880/50000 (22%)]	Loss: 1.804131
# Train Epoch: 2 [11520/50000 (23%)]	Loss: 1.973096
# Train Epoch: 2 [12160/50000 (24%)]	Loss: 2.113318
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 2.247848
# Train Epoch: 2 [13440/50000 (27%)]	Loss: 1.970786
# Train Epoch: 2 [14080/50000 (28%)]	Loss: 2.052663
# Train Epoch: 2 [14720/50000 (29%)]	Loss: 1.929168
# Train Epoch: 2 [15360/50000 (31%)]	Loss: 1.869774
# Train Epoch: 2 [16000/50000 (32%)]	Loss: 1.946175
# Train Epoch: 2 [16640/50000 (33%)]	Loss: 2.080901
# Train Epoch: 2 [17280/50000 (35%)]	Loss: 1.889886
# Train Epoch: 2 [17920/50000 (36%)]	Loss: 1.840694
# Train Epoch: 2 [18560/50000 (37%)]	Loss: 1.787866
# Train Epoch: 2 [19200/50000 (38%)]	Loss: 1.840415
# Train Epoch: 2 [19840/50000 (40%)]	Loss: 1.906598
# Train Epoch: 2 [20480/50000 (41%)]	Loss: 1.888432
# Train Epoch: 2 [21120/50000 (42%)]	Loss: 1.771680
# Train Epoch: 2 [21760/50000 (43%)]	Loss: 1.971810
# Train Epoch: 2 [22400/50000 (45%)]	Loss: 2.045365
# Train Epoch: 2 [23040/50000 (46%)]	Loss: 2.028326
# Train Epoch: 2 [23680/50000 (47%)]	Loss: 1.909869
# Train Epoch: 2 [24320/50000 (49%)]	Loss: 1.926820
# Train Epoch: 2 [24960/50000 (50%)]	Loss: 1.896007
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 1.858076
# Train Epoch: 2 [26240/50000 (52%)]	Loss: 1.900348
# Train Epoch: 2 [26880/50000 (54%)]	Loss: 1.814597
# Train Epoch: 2 [27520/50000 (55%)]	Loss: 1.995135
# Train Epoch: 2 [28160/50000 (56%)]	Loss: 1.942244
# Train Epoch: 2 [28800/50000 (58%)]	Loss: 1.707351
# Train Epoch: 2 [29440/50000 (59%)]	Loss: 1.736012
# Train Epoch: 2 [30080/50000 (60%)]	Loss: 1.886931
# Train Epoch: 2 [30720/50000 (61%)]	Loss: 1.746630
# Train Epoch: 2 [31360/50000 (63%)]	Loss: 2.164068
# Train Epoch: 2 [32000/50000 (64%)]	Loss: 2.036820
# Train Epoch: 2 [32640/50000 (65%)]	Loss: 1.867870
# Train Epoch: 2 [33280/50000 (66%)]	Loss: 1.921785
# Train Epoch: 2 [33920/50000 (68%)]	Loss: 1.832452
# Train Epoch: 2 [34560/50000 (69%)]	Loss: 1.882641
# Train Epoch: 2 [35200/50000 (70%)]	Loss: 1.924842
# Train Epoch: 2 [35840/50000 (72%)]	Loss: 1.862938
# Train Epoch: 2 [36480/50000 (73%)]	Loss: 1.832289
# Train Epoch: 2 [37120/50000 (74%)]	Loss: 1.835361
# Train Epoch: 2 [37760/50000 (75%)]	Loss: 1.969191
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 1.935953
# Train Epoch: 2 [39040/50000 (78%)]	Loss: 1.837178
# Train Epoch: 2 [39680/50000 (79%)]	Loss: 2.079106
# Train Epoch: 2 [40320/50000 (81%)]	Loss: 2.012868
# Train Epoch: 2 [40960/50000 (82%)]	Loss: 1.993462
# Train Epoch: 2 [41600/50000 (83%)]	Loss: 1.947679
# Train Epoch: 2 [42240/50000 (84%)]	Loss: 1.979266
# Train Epoch: 2 [42880/50000 (86%)]	Loss: 1.757149
# Train Epoch: 2 [43520/50000 (87%)]	Loss: 1.712762
# Train Epoch: 2 [44160/50000 (88%)]	Loss: 1.986242
# Train Epoch: 2 [44800/50000 (90%)]	Loss: 1.880518
# Train Epoch: 2 [45440/50000 (91%)]	Loss: 1.772846
# Train Epoch: 2 [46080/50000 (92%)]	Loss: 1.898052
# Train Epoch: 2 [46720/50000 (93%)]	Loss: 1.720931
# Train Epoch: 2 [47360/50000 (95%)]	Loss: 1.864599
# Train Epoch: 2 [48000/50000 (96%)]	Loss: 1.929160
# Train Epoch: 2 [48640/50000 (97%)]	Loss: 1.789497
# Train Epoch: 2 [49280/50000 (98%)]	Loss: 1.948905
# Train Epoch: 2 [49920/50000 (100%)]	Loss: 1.959782
#
# Test set: Avg. loss: 2.1182, Accuracy: 3102/10000 (31.0%)
#
#
# --- saving model for best accuracy ---
# --- saving finished ---
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 1.961651
# Train Epoch: 3 [640/50000 (1%)]	Loss: 1.833247
# Train Epoch: 3 [1280/50000 (3%)]	Loss: 1.912042
# Train Epoch: 3 [1920/50000 (4%)]	Loss: 1.836225
# Train Epoch: 3 [2560/50000 (5%)]	Loss: 1.784855
# Train Epoch: 3 [3200/50000 (6%)]	Loss: 1.944108
# Train Epoch: 3 [3840/50000 (8%)]	Loss: 1.777281
# Train Epoch: 3 [4480/50000 (9%)]	Loss: 1.833146
# Train Epoch: 3 [5120/50000 (10%)]	Loss: 1.740268
# Train Epoch: 3 [5760/50000 (12%)]	Loss: 1.765956
# Train Epoch: 3 [6400/50000 (13%)]	Loss: 1.678632
# Train Epoch: 3 [7040/50000 (14%)]	Loss: 1.758340
# Train Epoch: 3 [7680/50000 (15%)]	Loss: 1.647188
# Train Epoch: 3 [8320/50000 (17%)]	Loss: 1.770248
# Train Epoch: 3 [8960/50000 (18%)]	Loss: 1.768126
# Train Epoch: 3 [9600/50000 (19%)]	Loss: 2.021567
# Train Epoch: 3 [10240/50000 (20%)]	Loss: 1.966102
# Train Epoch: 3 [10880/50000 (22%)]	Loss: 1.720403
# Train Epoch: 3 [11520/50000 (23%)]	Loss: 1.783276
# Train Epoch: 3 [12160/50000 (24%)]	Loss: 1.875280
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 1.825856
# Train Epoch: 3 [13440/50000 (27%)]	Loss: 1.890326
# Train Epoch: 3 [14080/50000 (28%)]	Loss: 1.804032
# Train Epoch: 3 [14720/50000 (29%)]	Loss: 1.763040
# Train Epoch: 3 [15360/50000 (31%)]	Loss: 2.029246
# Train Epoch: 3 [16000/50000 (32%)]	Loss: 1.731935
# Train Epoch: 3 [16640/50000 (33%)]	Loss: 1.704309
# Train Epoch: 3 [17280/50000 (35%)]	Loss: 1.768491
# Train Epoch: 3 [17920/50000 (36%)]	Loss: 2.039624
# Train Epoch: 3 [18560/50000 (37%)]	Loss: 1.788000
# Train Epoch: 3 [19200/50000 (38%)]	Loss: 1.928299
# Train Epoch: 3 [19840/50000 (40%)]	Loss: 1.654202
# Train Epoch: 3 [20480/50000 (41%)]	Loss: 1.797699
# Train Epoch: 3 [21120/50000 (42%)]	Loss: 1.675943
# Train Epoch: 3 [21760/50000 (43%)]	Loss: 1.797631
# Train Epoch: 3 [22400/50000 (45%)]	Loss: 1.781558
# Train Epoch: 3 [23040/50000 (46%)]	Loss: 1.875849
# Train Epoch: 3 [23680/50000 (47%)]	Loss: 1.964985
# Train Epoch: 3 [24320/50000 (49%)]	Loss: 1.864073
# Train Epoch: 3 [24960/50000 (50%)]	Loss: 1.634851
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 1.674041
# Train Epoch: 3 [26240/50000 (52%)]	Loss: 1.604692
# Train Epoch: 3 [26880/50000 (54%)]	Loss: 1.783740
# Train Epoch: 3 [27520/50000 (55%)]	Loss: 1.863670
# Train Epoch: 3 [28160/50000 (56%)]	Loss: 1.643147
# Train Epoch: 3 [28800/50000 (58%)]	Loss: 1.673247
# Train Epoch: 3 [29440/50000 (59%)]	Loss: 1.896657
# Train Epoch: 3 [30080/50000 (60%)]	Loss: 1.738410
# Train Epoch: 3 [30720/50000 (61%)]	Loss: 1.724636
# Train Epoch: 3 [31360/50000 (63%)]	Loss: 1.680327
# Train Epoch: 3 [32000/50000 (64%)]	Loss: 1.862352
# Train Epoch: 3 [32640/50000 (65%)]	Loss: 1.837651
# Train Epoch: 3 [33280/50000 (66%)]	Loss: 1.706379
# Train Epoch: 3 [33920/50000 (68%)]	Loss: 1.954479
# Train Epoch: 3 [34560/50000 (69%)]	Loss: 1.787804
# Train Epoch: 3 [35200/50000 (70%)]	Loss: 1.812032
# Train Epoch: 3 [35840/50000 (72%)]	Loss: 2.021138
# Train Epoch: 3 [36480/50000 (73%)]	Loss: 2.009504
# Train Epoch: 3 [37120/50000 (74%)]	Loss: 1.934268
# Train Epoch: 3 [37760/50000 (75%)]	Loss: 1.851813
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 1.774913
# Train Epoch: 3 [39040/50000 (78%)]	Loss: 1.727492
# Train Epoch: 3 [39680/50000 (79%)]	Loss: 1.569368
# Train Epoch: 3 [40320/50000 (81%)]	Loss: 1.668689
# Train Epoch: 3 [40960/50000 (82%)]	Loss: 1.841076
# Train Epoch: 3 [41600/50000 (83%)]	Loss: 1.746465
# Train Epoch: 3 [42240/50000 (84%)]	Loss: 1.958202
# Train Epoch: 3 [42880/50000 (86%)]	Loss: 2.044396
# Train Epoch: 3 [43520/50000 (87%)]	Loss: 2.005336
# Train Epoch: 3 [44160/50000 (88%)]	Loss: 1.565696
# Train Epoch: 3 [44800/50000 (90%)]	Loss: 1.901172
# Train Epoch: 3 [45440/50000 (91%)]	Loss: 1.736193
# Train Epoch: 3 [46080/50000 (92%)]	Loss: 1.713609
# Train Epoch: 3 [46720/50000 (93%)]	Loss: 1.734375
# Train Epoch: 3 [47360/50000 (95%)]	Loss: 1.634175
# Train Epoch: 3 [48000/50000 (96%)]	Loss: 1.729998
# Train Epoch: 3 [48640/50000 (97%)]	Loss: 1.837250
# Train Epoch: 3 [49280/50000 (98%)]	Loss: 1.747160
# Train Epoch: 3 [49920/50000 (100%)]	Loss: 1.835621
#
# Test set: Avg. loss: 2.2602, Accuracy: 3060/10000 (30.6%)
#
#
# --- saving model for best accuracy ---
# --- saving finished ---
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 2.448285
# Train Epoch: 4 [640/50000 (1%)]	Loss: 1.737170
# Train Epoch: 4 [1280/50000 (3%)]	Loss: 1.802976
# Train Epoch: 4 [1920/50000 (4%)]	Loss: 1.778464
# Train Epoch: 4 [2560/50000 (5%)]	Loss: 1.717006
# Train Epoch: 4 [3200/50000 (6%)]	Loss: 1.926553
# Train Epoch: 4 [3840/50000 (8%)]	Loss: 1.699817
# Train Epoch: 4 [4480/50000 (9%)]	Loss: 2.003623
# Train Epoch: 4 [5120/50000 (10%)]	Loss: 1.612986
# Train Epoch: 4 [5760/50000 (12%)]	Loss: 1.523238
# Train Epoch: 4 [6400/50000 (13%)]	Loss: 1.734680
# Train Epoch: 4 [7040/50000 (14%)]	Loss: 1.818429
# Train Epoch: 4 [7680/50000 (15%)]	Loss: 1.917628
# Train Epoch: 4 [8320/50000 (17%)]	Loss: 1.508791
# Train Epoch: 4 [8960/50000 (18%)]	Loss: 1.876769
# Train Epoch: 4 [9600/50000 (19%)]	Loss: 1.598682
# Train Epoch: 4 [10240/50000 (20%)]	Loss: 1.696210
# Train Epoch: 4 [10880/50000 (22%)]	Loss: 1.827803
# Train Epoch: 4 [11520/50000 (23%)]	Loss: 1.746388
# Train Epoch: 4 [12160/50000 (24%)]	Loss: 1.651980
# Train Epoch: 4 [12800/50000 (26%)]	Loss: 1.587689
# Train Epoch: 4 [13440/50000 (27%)]	Loss: 1.953279
# Train Epoch: 4 [14080/50000 (28%)]	Loss: 1.768852
# Train Epoch: 4 [14720/50000 (29%)]	Loss: 1.696337
# Train Epoch: 4 [15360/50000 (31%)]	Loss: 1.769307
# Train Epoch: 4 [16000/50000 (32%)]	Loss: 1.818283
# Train Epoch: 4 [16640/50000 (33%)]	Loss: 1.580794
# Train Epoch: 4 [17280/50000 (35%)]	Loss: 1.579416
# Train Epoch: 4 [17920/50000 (36%)]	Loss: 1.838251
# Train Epoch: 4 [18560/50000 (37%)]	Loss: 1.868062
# Train Epoch: 4 [19200/50000 (38%)]	Loss: 1.760688
# Train Epoch: 4 [19840/50000 (40%)]	Loss: 1.709977
# Train Epoch: 4 [20480/50000 (41%)]	Loss: 1.738921
# Train Epoch: 4 [21120/50000 (42%)]	Loss: 1.715977
# Train Epoch: 4 [21760/50000 (43%)]	Loss: 1.727084
# Train Epoch: 4 [22400/50000 (45%)]	Loss: 1.478011
# Train Epoch: 4 [23040/50000 (46%)]	Loss: 1.798704
# Train Epoch: 4 [23680/50000 (47%)]	Loss: 1.679225
# Train Epoch: 4 [24320/50000 (49%)]	Loss: 1.785939
# Train Epoch: 4 [24960/50000 (50%)]	Loss: 1.793896
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 1.738096
# Train Epoch: 4 [26240/50000 (52%)]	Loss: 1.672649
# Train Epoch: 4 [26880/50000 (54%)]	Loss: 1.884199
# Train Epoch: 4 [27520/50000 (55%)]	Loss: 1.724032
# Train Epoch: 4 [28160/50000 (56%)]	Loss: 1.669502
# Train Epoch: 4 [28800/50000 (58%)]	Loss: 1.517591
# Train Epoch: 4 [29440/50000 (59%)]	Loss: 1.911783
# Train Epoch: 4 [30080/50000 (60%)]	Loss: 1.650694
# Train Epoch: 4 [30720/50000 (61%)]	Loss: 1.707091
# Train Epoch: 4 [31360/50000 (63%)]	Loss: 1.808600
# Train Epoch: 4 [32000/50000 (64%)]	Loss: 1.897354
# Train Epoch: 4 [32640/50000 (65%)]	Loss: 1.816789
# Train Epoch: 4 [33280/50000 (66%)]	Loss: 1.673802
# Train Epoch: 4 [33920/50000 (68%)]	Loss: 1.743301
# Train Epoch: 4 [34560/50000 (69%)]	Loss: 1.640738
# Train Epoch: 4 [35200/50000 (70%)]	Loss: 1.697016
# Train Epoch: 4 [35840/50000 (72%)]	Loss: 1.683459
# Train Epoch: 4 [36480/50000 (73%)]	Loss: 1.903050
# Train Epoch: 4 [37120/50000 (74%)]	Loss: 1.725486
# Train Epoch: 4 [37760/50000 (75%)]	Loss: 1.839879
# Train Epoch: 4 [38400/50000 (77%)]	Loss: 1.671432
# Train Epoch: 4 [39040/50000 (78%)]	Loss: 1.583292
# Train Epoch: 4 [39680/50000 (79%)]	Loss: 1.691955
# Train Epoch: 4 [40320/50000 (81%)]	Loss: 1.764759
# Train Epoch: 4 [40960/50000 (82%)]	Loss: 1.649593
# Train Epoch: 4 [41600/50000 (83%)]	Loss: 1.833676
# Train Epoch: 4 [42240/50000 (84%)]	Loss: 1.702461
# Train Epoch: 4 [42880/50000 (86%)]	Loss: 1.701233
# Train Epoch: 4 [43520/50000 (87%)]	Loss: 1.564838
# Train Epoch: 4 [44160/50000 (88%)]	Loss: 1.934927
# Train Epoch: 4 [44800/50000 (90%)]	Loss: 1.681849
# Train Epoch: 4 [45440/50000 (91%)]	Loss: 1.820681
# Train Epoch: 4 [46080/50000 (92%)]	Loss: 1.640620
# Train Epoch: 4 [46720/50000 (93%)]	Loss: 1.895116
# Train Epoch: 4 [47360/50000 (95%)]	Loss: 1.932509
# Train Epoch: 4 [48000/50000 (96%)]	Loss: 1.516410
# Train Epoch: 4 [48640/50000 (97%)]	Loss: 1.888136
# Train Epoch: 4 [49280/50000 (98%)]	Loss: 1.693425
# Train Epoch: 4 [49920/50000 (100%)]	Loss: 1.713258
#
# Test set: Avg. loss: 2.0124, Accuracy: 3350/10000 (33.5%)
#
#
# --- saving model for best accuracy ---
# --- saving finished ---
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 1.468154
# Train Epoch: 5 [640/50000 (1%)]	Loss: 1.514295
# Train Epoch: 5 [1280/50000 (3%)]	Loss: 1.770318
# Train Epoch: 5 [1920/50000 (4%)]	Loss: 1.644982
# Train Epoch: 5 [2560/50000 (5%)]	Loss: 1.640064
# Train Epoch: 5 [3200/50000 (6%)]	Loss: 1.647114
# Train Epoch: 5 [3840/50000 (8%)]	Loss: 1.583599
# Train Epoch: 5 [4480/50000 (9%)]	Loss: 1.659042
# Train Epoch: 5 [5120/50000 (10%)]	Loss: 1.829716
# Train Epoch: 5 [5760/50000 (12%)]	Loss: 1.727131
# Train Epoch: 5 [6400/50000 (13%)]	Loss: 1.584080
# Train Epoch: 5 [7040/50000 (14%)]	Loss: 1.525513
# Train Epoch: 5 [7680/50000 (15%)]	Loss: 1.883303
# Train Epoch: 5 [8320/50000 (17%)]	Loss: 1.620928
# Train Epoch: 5 [8960/50000 (18%)]	Loss: 1.568077
# Train Epoch: 5 [9600/50000 (19%)]	Loss: 1.455621
# Train Epoch: 5 [10240/50000 (20%)]	Loss: 1.628424
# Train Epoch: 5 [10880/50000 (22%)]	Loss: 1.672359
# Train Epoch: 5 [11520/50000 (23%)]	Loss: 1.613516
# Train Epoch: 5 [12160/50000 (24%)]	Loss: 1.858108
# Train Epoch: 5 [12800/50000 (26%)]	Loss: 1.846249
# Train Epoch: 5 [13440/50000 (27%)]	Loss: 1.760216
# Train Epoch: 5 [14080/50000 (28%)]	Loss: 1.643385
# Train Epoch: 5 [14720/50000 (29%)]	Loss: 1.571041
# Train Epoch: 5 [15360/50000 (31%)]	Loss: 1.792286
# Train Epoch: 5 [16000/50000 (32%)]	Loss: 1.621124
# Train Epoch: 5 [16640/50000 (33%)]	Loss: 1.817633
# Train Epoch: 5 [17280/50000 (35%)]	Loss: 1.546881
# Train Epoch: 5 [17920/50000 (36%)]	Loss: 1.718357
# Train Epoch: 5 [18560/50000 (37%)]	Loss: 1.526249
# Train Epoch: 5 [19200/50000 (38%)]	Loss: 1.660285
# Train Epoch: 5 [19840/50000 (40%)]	Loss: 1.691465
# Train Epoch: 5 [20480/50000 (41%)]	Loss: 1.519187
# Train Epoch: 5 [21120/50000 (42%)]	Loss: 1.652141
# Train Epoch: 5 [21760/50000 (43%)]	Loss: 1.573578
# Train Epoch: 5 [22400/50000 (45%)]	Loss: 1.746909
# Train Epoch: 5 [23040/50000 (46%)]	Loss: 1.848940
# Train Epoch: 5 [23680/50000 (47%)]	Loss: 1.781498
# Train Epoch: 5 [24320/50000 (49%)]	Loss: 1.707383
# Train Epoch: 5 [24960/50000 (50%)]	Loss: 1.582175
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 1.533690
# Train Epoch: 5 [26240/50000 (52%)]	Loss: 1.631725
# Train Epoch: 5 [26880/50000 (54%)]	Loss: 1.768165
# Train Epoch: 5 [27520/50000 (55%)]	Loss: 1.773714
# Train Epoch: 5 [28160/50000 (56%)]	Loss: 1.595134
# Train Epoch: 5 [28800/50000 (58%)]	Loss: 1.558434
# Train Epoch: 5 [29440/50000 (59%)]	Loss: 1.686655
# Train Epoch: 5 [30080/50000 (60%)]	Loss: 1.512231
# Train Epoch: 5 [30720/50000 (61%)]	Loss: 1.520969
# Train Epoch: 5 [31360/50000 (63%)]	Loss: 1.573736
# Train Epoch: 5 [32000/50000 (64%)]	Loss: 1.671271
# Train Epoch: 5 [32640/50000 (65%)]	Loss: 1.589819
# Train Epoch: 5 [33280/50000 (66%)]	Loss: 1.496264
# Train Epoch: 5 [33920/50000 (68%)]	Loss: 1.662609
# Train Epoch: 5 [34560/50000 (69%)]	Loss: 1.834603
# Train Epoch: 5 [35200/50000 (70%)]	Loss: 1.492055
# Train Epoch: 5 [35840/50000 (72%)]	Loss: 1.475241
# Train Epoch: 5 [36480/50000 (73%)]	Loss: 1.713762
# Train Epoch: 5 [37120/50000 (74%)]	Loss: 1.695732
# Train Epoch: 5 [37760/50000 (75%)]	Loss: 1.734314
# Train Epoch: 5 [38400/50000 (77%)]	Loss: 1.650864
# Train Epoch: 5 [39040/50000 (78%)]	Loss: 1.799159
# Train Epoch: 5 [39680/50000 (79%)]	Loss: 1.589175
# Train Epoch: 5 [40320/50000 (81%)]	Loss: 1.687664
# Train Epoch: 5 [40960/50000 (82%)]	Loss: 1.469210
# Train Epoch: 5 [41600/50000 (83%)]	Loss: 1.855446
# Train Epoch: 5 [42240/50000 (84%)]	Loss: 1.702517
# Train Epoch: 5 [42880/50000 (86%)]	Loss: 1.624901
# Train Epoch: 5 [43520/50000 (87%)]	Loss: 1.515022
# Train Epoch: 5 [44160/50000 (88%)]	Loss: 1.683042
# Train Epoch: 5 [44800/50000 (90%)]	Loss: 1.673175
# Train Epoch: 5 [45440/50000 (91%)]	Loss: 1.519582
# Train Epoch: 5 [46080/50000 (92%)]	Loss: 1.462952
# Train Epoch: 5 [46720/50000 (93%)]	Loss: 1.608548
# Train Epoch: 5 [47360/50000 (95%)]	Loss: 1.655177
# Train Epoch: 5 [48000/50000 (96%)]	Loss: 1.844491
# Train Epoch: 5 [48640/50000 (97%)]	Loss: 1.607525
# Train Epoch: 5 [49280/50000 (98%)]	Loss: 1.757437
# Train Epoch: 5 [49920/50000 (100%)]	Loss: 1.809901
#
# Test set: Avg. loss: 2.0253, Accuracy: 3255/10000 (32.5%)
#
#
# --- saving model for best accuracy ---
# --- saving finished ---
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 1.701078
# Train Epoch: 6 [640/50000 (1%)]	Loss: 1.553664
# Train Epoch: 6 [1280/50000 (3%)]	Loss: 1.707240
# Train Epoch: 6 [1920/50000 (4%)]	Loss: 1.666096
# Train Epoch: 6 [2560/50000 (5%)]	Loss: 1.664222
# Train Epoch: 6 [3200/50000 (6%)]	Loss: 1.509451
# Train Epoch: 6 [3840/50000 (8%)]	Loss: 1.668950
# Train Epoch: 6 [4480/50000 (9%)]	Loss: 1.519208
# Train Epoch: 6 [5120/50000 (10%)]	Loss: 1.723330
# Train Epoch: 6 [5760/50000 (12%)]	Loss: 1.522283
# Train Epoch: 6 [6400/50000 (13%)]	Loss: 1.691246
# Train Epoch: 6 [7040/50000 (14%)]	Loss: 1.617741
# Train Epoch: 6 [7680/50000 (15%)]	Loss: 1.479503
# Train Epoch: 6 [8320/50000 (17%)]	Loss: 1.511472
# Train Epoch: 6 [8960/50000 (18%)]	Loss: 1.649747
# Train Epoch: 6 [9600/50000 (19%)]	Loss: 1.799119
# Train Epoch: 6 [10240/50000 (20%)]	Loss: 1.782739
# Train Epoch: 6 [10880/50000 (22%)]	Loss: 1.494034
# Train Epoch: 6 [11520/50000 (23%)]	Loss: 1.607621
# Train Epoch: 6 [12160/50000 (24%)]	Loss: 1.787883
# Train Epoch: 6 [12800/50000 (26%)]	Loss: 1.485859
# Train Epoch: 6 [13440/50000 (27%)]	Loss: 1.556316
# Train Epoch: 6 [14080/50000 (28%)]	Loss: 1.546451
# Train Epoch: 6 [14720/50000 (29%)]	Loss: 1.683374
# Train Epoch: 6 [15360/50000 (31%)]	Loss: 1.675647
# Train Epoch: 6 [16000/50000 (32%)]	Loss: 1.498559
# Train Epoch: 6 [16640/50000 (33%)]	Loss: 1.550119
# Train Epoch: 6 [17280/50000 (35%)]	Loss: 1.659999
# Train Epoch: 6 [17920/50000 (36%)]	Loss: 1.773374
# Train Epoch: 6 [18560/50000 (37%)]	Loss: 1.539415
# Train Epoch: 6 [19200/50000 (38%)]	Loss: 1.461601
# Train Epoch: 6 [19840/50000 (40%)]	Loss: 1.571471
# Train Epoch: 6 [20480/50000 (41%)]	Loss: 1.523949
# Train Epoch: 6 [21120/50000 (42%)]	Loss: 1.873856
# Train Epoch: 6 [21760/50000 (43%)]	Loss: 1.771916
# Train Epoch: 6 [22400/50000 (45%)]	Loss: 1.723924
# Train Epoch: 6 [23040/50000 (46%)]	Loss: 1.613214
# Train Epoch: 6 [23680/50000 (47%)]	Loss: 1.708705
# Train Epoch: 6 [24320/50000 (49%)]	Loss: 1.519108
# Train Epoch: 6 [24960/50000 (50%)]	Loss: 1.855134
# Train Epoch: 6 [25600/50000 (51%)]	Loss: 1.650991
# Train Epoch: 6 [26240/50000 (52%)]	Loss: 1.615024
# Train Epoch: 6 [26880/50000 (54%)]	Loss: 1.582811
# Train Epoch: 6 [27520/50000 (55%)]	Loss: 1.488839
# Train Epoch: 6 [28160/50000 (56%)]	Loss: 1.610503
# Train Epoch: 6 [28800/50000 (58%)]	Loss: 1.513338
# Train Epoch: 6 [29440/50000 (59%)]	Loss: 1.576622
# Train Epoch: 6 [30080/50000 (60%)]	Loss: 1.611783
# Train Epoch: 6 [30720/50000 (61%)]	Loss: 1.731084
# Train Epoch: 6 [31360/50000 (63%)]	Loss: 1.641869
# Train Epoch: 6 [32000/50000 (64%)]	Loss: 1.619358
# Train Epoch: 6 [32640/50000 (65%)]	Loss: 1.757800
# Train Epoch: 6 [33280/50000 (66%)]	Loss: 1.692364
# Train Epoch: 6 [33920/50000 (68%)]	Loss: 1.529982
# Train Epoch: 6 [34560/50000 (69%)]	Loss: 1.525518
# Train Epoch: 6 [35200/50000 (70%)]	Loss: 1.556595
# Train Epoch: 6 [35840/50000 (72%)]	Loss: 1.534233
# Train Epoch: 6 [36480/50000 (73%)]	Loss: 1.678481
# Train Epoch: 6 [37120/50000 (74%)]	Loss: 1.699684
# Train Epoch: 6 [37760/50000 (75%)]	Loss: 1.531490
# Train Epoch: 6 [38400/50000 (77%)]	Loss: 1.556224
# Train Epoch: 6 [39040/50000 (78%)]	Loss: 1.671795
# Train Epoch: 6 [39680/50000 (79%)]	Loss: 1.855713
# Train Epoch: 6 [40320/50000 (81%)]	Loss: 1.875822
# Train Epoch: 6 [40960/50000 (82%)]	Loss: 1.528081
# Train Epoch: 6 [41600/50000 (83%)]	Loss: 1.520269
# Train Epoch: 6 [42240/50000 (84%)]	Loss: 1.698409
# Train Epoch: 6 [42880/50000 (86%)]	Loss: 1.615551
# Train Epoch: 6 [43520/50000 (87%)]	Loss: 1.485114
# Train Epoch: 6 [44160/50000 (88%)]	Loss: 1.784077
# Train Epoch: 6 [44800/50000 (90%)]	Loss: 1.438506
# Train Epoch: 6 [45440/50000 (91%)]	Loss: 1.559908
# Train Epoch: 6 [46080/50000 (92%)]	Loss: 1.549672
# Train Epoch: 6 [46720/50000 (93%)]	Loss: 1.660580
# Train Epoch: 6 [47360/50000 (95%)]	Loss: 1.752894
# Train Epoch: 6 [48000/50000 (96%)]	Loss: 1.874043
# Train Epoch: 6 [48640/50000 (97%)]	Loss: 1.623163
# Train Epoch: 6 [49280/50000 (98%)]	Loss: 1.707183
# Train Epoch: 6 [49920/50000 (100%)]	Loss: 1.699764
#
# Test set: Avg. loss: 1.9667, Accuracy: 3486/10000 (34.9%)
#
#
# --- saving model for best accuracy ---
# --- saving finished ---
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 1.684442
# Train Epoch: 7 [640/50000 (1%)]	Loss: 1.417900
# Train Epoch: 7 [1280/50000 (3%)]	Loss: 1.358491
# Train Epoch: 7 [1920/50000 (4%)]	Loss: 1.421486
# Train Epoch: 7 [2560/50000 (5%)]	Loss: 1.347942
# Train Epoch: 7 [3200/50000 (6%)]	Loss: 1.559193
# Train Epoch: 7 [3840/50000 (8%)]	Loss: 1.710923
# Train Epoch: 7 [4480/50000 (9%)]	Loss: 1.459280
# Train Epoch: 7 [5120/50000 (10%)]	Loss: 1.567785
# Train Epoch: 7 [5760/50000 (12%)]	Loss: 1.415496
# Train Epoch: 7 [6400/50000 (13%)]	Loss: 1.405406
# Train Epoch: 7 [7040/50000 (14%)]	Loss: 1.376972
# Train Epoch: 7 [7680/50000 (15%)]	Loss: 1.501440
# Train Epoch: 7 [8320/50000 (17%)]	Loss: 1.590819
# Train Epoch: 7 [8960/50000 (18%)]	Loss: 1.585952
# Train Epoch: 7 [9600/50000 (19%)]	Loss: 1.806883
# Train Epoch: 7 [10240/50000 (20%)]	Loss: 1.583002
# Train Epoch: 7 [10880/50000 (22%)]	Loss: 1.497048
# Train Epoch: 7 [11520/50000 (23%)]	Loss: 1.964240
# Train Epoch: 7 [12160/50000 (24%)]	Loss: 1.502064
# Train Epoch: 7 [12800/50000 (26%)]	Loss: 1.439909
# Train Epoch: 7 [13440/50000 (27%)]	Loss: 1.523356
# Train Epoch: 7 [14080/50000 (28%)]	Loss: 1.641983
# Train Epoch: 7 [14720/50000 (29%)]	Loss: 1.477821
# Train Epoch: 7 [15360/50000 (31%)]	Loss: 1.556367
# Train Epoch: 7 [16000/50000 (32%)]	Loss: 1.461160
# Train Epoch: 7 [16640/50000 (33%)]	Loss: 1.660496
# Train Epoch: 7 [17280/50000 (35%)]	Loss: 1.295617
# Train Epoch: 7 [17920/50000 (36%)]	Loss: 1.499335
# Train Epoch: 7 [18560/50000 (37%)]	Loss: 1.505298
# Train Epoch: 7 [19200/50000 (38%)]	Loss: 1.342606
# Train Epoch: 7 [19840/50000 (40%)]	Loss: 1.683792
# Train Epoch: 7 [20480/50000 (41%)]	Loss: 1.400362
# Train Epoch: 7 [21120/50000 (42%)]	Loss: 1.590353
# Train Epoch: 7 [21760/50000 (43%)]	Loss: 1.398699
# Train Epoch: 7 [22400/50000 (45%)]	Loss: 1.679177
# Train Epoch: 7 [23040/50000 (46%)]	Loss: 1.696269
# Train Epoch: 7 [23680/50000 (47%)]	Loss: 1.677794
# Train Epoch: 7 [24320/50000 (49%)]	Loss: 1.512394
# Train Epoch: 7 [24960/50000 (50%)]	Loss: 1.676537
# Train Epoch: 7 [25600/50000 (51%)]	Loss: 1.582457
# Train Epoch: 7 [26240/50000 (52%)]	Loss: 1.583830
# Train Epoch: 7 [26880/50000 (54%)]	Loss: 1.407096
# Train Epoch: 7 [27520/50000 (55%)]	Loss: 1.725499
# Train Epoch: 7 [28160/50000 (56%)]	Loss: 1.709885
# Train Epoch: 7 [28800/50000 (58%)]	Loss: 1.618087
# Train Epoch: 7 [29440/50000 (59%)]	Loss: 1.680119
# Train Epoch: 7 [30080/50000 (60%)]	Loss: 1.450479
# Train Epoch: 7 [30720/50000 (61%)]	Loss: 1.592850
# Train Epoch: 7 [31360/50000 (63%)]	Loss: 1.685295
# Train Epoch: 7 [32000/50000 (64%)]	Loss: 1.410060
# Train Epoch: 7 [32640/50000 (65%)]	Loss: 1.569969
# Train Epoch: 7 [33280/50000 (66%)]	Loss: 1.445351
# Train Epoch: 7 [33920/50000 (68%)]	Loss: 1.820744
# Train Epoch: 7 [34560/50000 (69%)]	Loss: 1.655738
# Train Epoch: 7 [35200/50000 (70%)]	Loss: 1.611211
# Train Epoch: 7 [35840/50000 (72%)]	Loss: 1.539264
# Train Epoch: 7 [36480/50000 (73%)]	Loss: 1.538105
# Train Epoch: 7 [37120/50000 (74%)]	Loss: 1.718103
# Train Epoch: 7 [37760/50000 (75%)]	Loss: 1.465041
# Train Epoch: 7 [38400/50000 (77%)]	Loss: 1.428696
# Train Epoch: 7 [39040/50000 (78%)]	Loss: 1.737584
# Train Epoch: 7 [39680/50000 (79%)]	Loss: 1.518082
# Train Epoch: 7 [40320/50000 (81%)]	Loss: 1.746377
# Train Epoch: 7 [40960/50000 (82%)]	Loss: 1.616206
# Train Epoch: 7 [41600/50000 (83%)]	Loss: 1.525709
# Train Epoch: 7 [42240/50000 (84%)]	Loss: 1.414178
# Train Epoch: 7 [42880/50000 (86%)]	Loss: 1.744716
# Train Epoch: 7 [43520/50000 (87%)]	Loss: 1.514294
# Train Epoch: 7 [44160/50000 (88%)]	Loss: 1.584164
# Train Epoch: 7 [44800/50000 (90%)]	Loss: 1.446098
# Train Epoch: 7 [45440/50000 (91%)]	Loss: 1.302812
# Train Epoch: 7 [46080/50000 (92%)]	Loss: 1.646225
# Train Epoch: 7 [46720/50000 (93%)]	Loss: 1.674317
# Train Epoch: 7 [47360/50000 (95%)]	Loss: 1.330325
# Train Epoch: 7 [48000/50000 (96%)]	Loss: 1.602832
# Train Epoch: 7 [48640/50000 (97%)]	Loss: 1.669439
# Train Epoch: 7 [49280/50000 (98%)]	Loss: 1.525136
# Train Epoch: 7 [49920/50000 (100%)]	Loss: 1.491569
#
# Test set: Avg. loss: 2.1157, Accuracy: 2968/10000 (29.7%)
#
#
# --- saving model for best accuracy ---
# --- saving finished ---
#
# Train Epoch: 8 [0/50000 (0%)]	Loss: 1.723389
# Train Epoch: 8 [640/50000 (1%)]	Loss: 1.560183
# Train Epoch: 8 [1280/50000 (3%)]	Loss: 1.525420
# Train Epoch: 8 [1920/50000 (4%)]	Loss: 1.408478
# Train Epoch: 8 [2560/50000 (5%)]	Loss: 1.479989
# Train Epoch: 8 [3200/50000 (6%)]	Loss: 1.459012
# Train Epoch: 8 [3840/50000 (8%)]	Loss: 1.356841
# Train Epoch: 8 [4480/50000 (9%)]	Loss: 1.367157
# Train Epoch: 8 [5120/50000 (10%)]	Loss: 1.476657
# Train Epoch: 8 [5760/50000 (12%)]	Loss: 1.334399
# Train Epoch: 8 [6400/50000 (13%)]	Loss: 1.628641
# Train Epoch: 8 [7040/50000 (14%)]	Loss: 1.622309
# Train Epoch: 8 [7680/50000 (15%)]	Loss: 1.583133
# Train Epoch: 8 [8320/50000 (17%)]	Loss: 1.451860
# Train Epoch: 8 [8960/50000 (18%)]	Loss: 1.403381
# Train Epoch: 8 [9600/50000 (19%)]	Loss: 1.653681
# Train Epoch: 8 [10240/50000 (20%)]	Loss: 1.451215
# Train Epoch: 8 [10880/50000 (22%)]	Loss: 1.632998
# Train Epoch: 8 [11520/50000 (23%)]	Loss: 1.313618
# Train Epoch: 8 [12160/50000 (24%)]	Loss: 1.355440
# Train Epoch: 8 [12800/50000 (26%)]	Loss: 1.407752
# Train Epoch: 8 [13440/50000 (27%)]	Loss: 1.495984
# Train Epoch: 8 [14080/50000 (28%)]	Loss: 1.364527
# Train Epoch: 8 [14720/50000 (29%)]	Loss: 1.687725
# Train Epoch: 8 [15360/50000 (31%)]	Loss: 1.327696
# Train Epoch: 8 [16000/50000 (32%)]	Loss: 1.410614
# Train Epoch: 8 [16640/50000 (33%)]	Loss: 1.577012
# Train Epoch: 8 [17280/50000 (35%)]	Loss: 1.490415
# Train Epoch: 8 [17920/50000 (36%)]	Loss: 1.697055
# Train Epoch: 8 [18560/50000 (37%)]	Loss: 1.486633
# Train Epoch: 8 [19200/50000 (38%)]	Loss: 1.414372
# Train Epoch: 8 [19840/50000 (40%)]	Loss: 1.669931
# Train Epoch: 8 [20480/50000 (41%)]	Loss: 1.580225
# Train Epoch: 8 [21120/50000 (42%)]	Loss: 1.588427
# Train Epoch: 8 [21760/50000 (43%)]	Loss: 1.692275
# Train Epoch: 8 [22400/50000 (45%)]	Loss: 1.471265
# Train Epoch: 8 [23040/50000 (46%)]	Loss: 1.473232
# Train Epoch: 8 [23680/50000 (47%)]	Loss: 1.717087
# Train Epoch: 8 [24320/50000 (49%)]	Loss: 1.582723
# Train Epoch: 8 [24960/50000 (50%)]	Loss: 1.510885
# Train Epoch: 8 [25600/50000 (51%)]	Loss: 1.739864
# Train Epoch: 8 [26240/50000 (52%)]	Loss: 1.510480
# Train Epoch: 8 [26880/50000 (54%)]	Loss: 1.533887
# Train Epoch: 8 [27520/50000 (55%)]	Loss: 1.219720
# Train Epoch: 8 [28160/50000 (56%)]	Loss: 1.472234
# Train Epoch: 8 [28800/50000 (58%)]	Loss: 1.519590
# Train Epoch: 8 [29440/50000 (59%)]	Loss: 1.456434
# Train Epoch: 8 [30080/50000 (60%)]	Loss: 1.433310
# Train Epoch: 8 [30720/50000 (61%)]	Loss: 1.567422
# Train Epoch: 8 [31360/50000 (63%)]	Loss: 1.297521
# Train Epoch: 8 [32000/50000 (64%)]	Loss: 1.555566
# Train Epoch: 8 [32640/50000 (65%)]	Loss: 1.691076
# Train Epoch: 8 [33280/50000 (66%)]	Loss: 1.325985
# Train Epoch: 8 [33920/50000 (68%)]	Loss: 1.523445
# Train Epoch: 8 [34560/50000 (69%)]	Loss: 1.735393
# Train Epoch: 8 [35200/50000 (70%)]	Loss: 1.354503
# Train Epoch: 8 [35840/50000 (72%)]	Loss: 1.497615
# Train Epoch: 8 [36480/50000 (73%)]	Loss: 1.501711
# Train Epoch: 8 [37120/50000 (74%)]	Loss: 1.685240
# Train Epoch: 8 [37760/50000 (75%)]	Loss: 1.723717
# Train Epoch: 8 [38400/50000 (77%)]	Loss: 1.639009
# Train Epoch: 8 [39040/50000 (78%)]	Loss: 1.431567
# Train Epoch: 8 [39680/50000 (79%)]	Loss: 1.570419
# Train Epoch: 8 [40320/50000 (81%)]	Loss: 1.396366
# Train Epoch: 8 [40960/50000 (82%)]	Loss: 1.654688
# Train Epoch: 8 [41600/50000 (83%)]	Loss: 1.407746
# Train Epoch: 8 [42240/50000 (84%)]	Loss: 1.559035
# Train Epoch: 8 [42880/50000 (86%)]	Loss: 1.590417
# Train Epoch: 8 [43520/50000 (87%)]	Loss: 1.533469
# Train Epoch: 8 [44160/50000 (88%)]	Loss: 1.580362
# Train Epoch: 8 [44800/50000 (90%)]	Loss: 1.781983
# Train Epoch: 8 [45440/50000 (91%)]	Loss: 1.617372
# Train Epoch: 8 [46080/50000 (92%)]	Loss: 1.621327
# Train Epoch: 8 [46720/50000 (93%)]	Loss: 1.621061
# Train Epoch: 8 [47360/50000 (95%)]	Loss: 1.428970
# Train Epoch: 8 [48000/50000 (96%)]	Loss: 1.575071
# Train Epoch: 8 [48640/50000 (97%)]	Loss: 1.556174
# Train Epoch: 8 [49280/50000 (98%)]	Loss: 1.609784
# Train Epoch: 8 [49920/50000 (100%)]	Loss: 1.456044
#
# Test set: Avg. loss: 2.0658, Accuracy: 3299/10000 (33.0%)
#
#
# --- saving model for best accuracy ---
# --- saving finished ---
#
# Train Epoch: 9 [0/50000 (0%)]	Loss: 1.560885
# Train Epoch: 9 [640/50000 (1%)]	Loss: 1.411808
# Train Epoch: 9 [1280/50000 (3%)]	Loss: 1.546003
# Train Epoch: 9 [1920/50000 (4%)]	Loss: 1.554146
# Train Epoch: 9 [2560/50000 (5%)]	Loss: 1.705313
# Train Epoch: 9 [3200/50000 (6%)]	Loss: 1.321830
# Train Epoch: 9 [3840/50000 (8%)]	Loss: 1.311318
# Train Epoch: 9 [4480/50000 (9%)]	Loss: 1.487846
# Train Epoch: 9 [5120/50000 (10%)]	Loss: 1.439065
# Train Epoch: 9 [5760/50000 (12%)]	Loss: 1.613749
# Train Epoch: 9 [6400/50000 (13%)]	Loss: 1.583021
# Train Epoch: 9 [7040/50000 (14%)]	Loss: 1.563333
# Train Epoch: 9 [7680/50000 (15%)]	Loss: 1.452873
# Train Epoch: 9 [8320/50000 (17%)]	Loss: 1.391982
# Train Epoch: 9 [8960/50000 (18%)]	Loss: 1.515270
# Train Epoch: 9 [9600/50000 (19%)]	Loss: 1.536421
# Train Epoch: 9 [10240/50000 (20%)]	Loss: 1.497410
# Train Epoch: 9 [10880/50000 (22%)]	Loss: 1.382710
# Train Epoch: 9 [11520/50000 (23%)]	Loss: 1.479907
# Train Epoch: 9 [12160/50000 (24%)]	Loss: 1.500831
# Train Epoch: 9 [12800/50000 (26%)]	Loss: 1.705543
# Train Epoch: 9 [13440/50000 (27%)]	Loss: 1.486550
# Train Epoch: 9 [14080/50000 (28%)]	Loss: 1.393416
# Train Epoch: 9 [14720/50000 (29%)]	Loss: 1.499411
# Train Epoch: 9 [15360/50000 (31%)]	Loss: 1.322924
# Train Epoch: 9 [16000/50000 (32%)]	Loss: 1.337286
# Train Epoch: 9 [16640/50000 (33%)]	Loss: 1.581905
# Train Epoch: 9 [17280/50000 (35%)]	Loss: 1.520458
# Train Epoch: 9 [17920/50000 (36%)]	Loss: 1.366283
# Train Epoch: 9 [18560/50000 (37%)]	Loss: 1.473494
# Train Epoch: 9 [19200/50000 (38%)]	Loss: 1.478820
# Train Epoch: 9 [19840/50000 (40%)]	Loss: 1.563112
# Train Epoch: 9 [20480/50000 (41%)]	Loss: 1.305347
# Train Epoch: 9 [21120/50000 (42%)]	Loss: 1.620287
# Train Epoch: 9 [21760/50000 (43%)]	Loss: 1.532720
# Train Epoch: 9 [22400/50000 (45%)]	Loss: 1.622084
# Train Epoch: 9 [23040/50000 (46%)]	Loss: 1.392953
# Train Epoch: 9 [23680/50000 (47%)]	Loss: 1.477307
# Train Epoch: 9 [24320/50000 (49%)]	Loss: 1.564047
# Train Epoch: 9 [24960/50000 (50%)]	Loss: 1.552337
# Train Epoch: 9 [25600/50000 (51%)]	Loss: 1.465770
# Train Epoch: 9 [26240/50000 (52%)]	Loss: 1.424648
# Train Epoch: 9 [26880/50000 (54%)]	Loss: 1.561661
# Train Epoch: 9 [27520/50000 (55%)]	Loss: 1.412908
# Train Epoch: 9 [28160/50000 (56%)]	Loss: 1.559148
# Train Epoch: 9 [28800/50000 (58%)]	Loss: 1.397098
# Train Epoch: 9 [29440/50000 (59%)]	Loss: 1.695415
# Train Epoch: 9 [30080/50000 (60%)]	Loss: 1.505538
# Train Epoch: 9 [30720/50000 (61%)]	Loss: 1.407747
# Train Epoch: 9 [31360/50000 (63%)]	Loss: 1.429239
# Train Epoch: 9 [32000/50000 (64%)]	Loss: 1.500715
# Train Epoch: 9 [32640/50000 (65%)]	Loss: 1.570714
# Train Epoch: 9 [33280/50000 (66%)]	Loss: 1.520154
# Train Epoch: 9 [33920/50000 (68%)]	Loss: 1.305085
# Train Epoch: 9 [34560/50000 (69%)]	Loss: 1.593115
# Train Epoch: 9 [35200/50000 (70%)]	Loss: 1.433738
# Train Epoch: 9 [35840/50000 (72%)]	Loss: 1.384441
# Train Epoch: 9 [36480/50000 (73%)]	Loss: 1.506991
# Train Epoch: 9 [37120/50000 (74%)]	Loss: 1.615527
# Train Epoch: 9 [37760/50000 (75%)]	Loss: 1.593037
# Train Epoch: 9 [38400/50000 (77%)]	Loss: 1.549752
# Train Epoch: 9 [39040/50000 (78%)]	Loss: 1.604880
# Train Epoch: 9 [39680/50000 (79%)]	Loss: 1.294791
# Train Epoch: 9 [40320/50000 (81%)]	Loss: 1.524527
# Train Epoch: 9 [40960/50000 (82%)]	Loss: 1.674934
# Train Epoch: 9 [41600/50000 (83%)]	Loss: 1.736004
# Train Epoch: 9 [42240/50000 (84%)]	Loss: 1.354290
# Train Epoch: 9 [42880/50000 (86%)]	Loss: 1.379414
# Train Epoch: 9 [43520/50000 (87%)]	Loss: 1.630174
# Train Epoch: 9 [44160/50000 (88%)]	Loss: 1.360358
# Train Epoch: 9 [44800/50000 (90%)]	Loss: 1.562284
# Train Epoch: 9 [45440/50000 (91%)]	Loss: 1.409461
# Train Epoch: 9 [46080/50000 (92%)]	Loss: 1.446828
# Train Epoch: 9 [46720/50000 (93%)]	Loss: 1.636854
# Train Epoch: 9 [47360/50000 (95%)]	Loss: 1.612902
# Train Epoch: 9 [48000/50000 (96%)]	Loss: 1.575122
# Train Epoch: 9 [48640/50000 (97%)]	Loss: 1.599089
# Train Epoch: 9 [49280/50000 (98%)]	Loss: 1.745565
# Train Epoch: 9 [49920/50000 (100%)]	Loss: 1.591365
#
# Test set: Avg. loss: 2.1876, Accuracy: 2952/10000 (29.5%)
#
#
# --- saving model for best accuracy ---
# --- saving finished ---
#
# Train Epoch: 10 [0/50000 (0%)]	Loss: 1.707407
# Train Epoch: 10 [640/50000 (1%)]	Loss: 1.568563
# Train Epoch: 10 [1280/50000 (3%)]	Loss: 1.382918
# Train Epoch: 10 [1920/50000 (4%)]	Loss: 1.467952
# Train Epoch: 10 [2560/50000 (5%)]	Loss: 1.577184
# Train Epoch: 10 [3200/50000 (6%)]	Loss: 1.524460
# Train Epoch: 10 [3840/50000 (8%)]	Loss: 1.551557
# Train Epoch: 10 [4480/50000 (9%)]	Loss: 1.132745
# Train Epoch: 10 [5120/50000 (10%)]	Loss: 1.363061
# Train Epoch: 10 [5760/50000 (12%)]	Loss: 1.567768
# Train Epoch: 10 [6400/50000 (13%)]	Loss: 1.604651
# Train Epoch: 10 [7040/50000 (14%)]	Loss: 1.468997
# Train Epoch: 10 [7680/50000 (15%)]	Loss: 1.551213
# Train Epoch: 10 [8320/50000 (17%)]	Loss: 1.416842
# Train Epoch: 10 [8960/50000 (18%)]	Loss: 1.363166
# Train Epoch: 10 [9600/50000 (19%)]	Loss: 1.715330
# Train Epoch: 10 [10240/50000 (20%)]	Loss: 1.252175
# Train Epoch: 10 [10880/50000 (22%)]	Loss: 1.225974
# Train Epoch: 10 [11520/50000 (23%)]	Loss: 1.461486
# Train Epoch: 10 [12160/50000 (24%)]	Loss: 1.493365
# Train Epoch: 10 [12800/50000 (26%)]	Loss: 1.357588
# Train Epoch: 10 [13440/50000 (27%)]	Loss: 1.581053
# Train Epoch: 10 [14080/50000 (28%)]	Loss: 1.550911
# Train Epoch: 10 [14720/50000 (29%)]	Loss: 1.553956
# Train Epoch: 10 [15360/50000 (31%)]	Loss: 1.480772
# Train Epoch: 10 [16000/50000 (32%)]	Loss: 1.337343
# Train Epoch: 10 [16640/50000 (33%)]	Loss: 1.721693
# Train Epoch: 10 [17280/50000 (35%)]	Loss: 1.604616
# Train Epoch: 10 [17920/50000 (36%)]	Loss: 1.426094
# Train Epoch: 10 [18560/50000 (37%)]	Loss: 1.488065
# Train Epoch: 10 [19200/50000 (38%)]	Loss: 1.374661
# Train Epoch: 10 [19840/50000 (40%)]	Loss: 1.277002
# Train Epoch: 10 [20480/50000 (41%)]	Loss: 1.528885
# Train Epoch: 10 [21120/50000 (42%)]	Loss: 1.460127
# Train Epoch: 10 [21760/50000 (43%)]	Loss: 1.588377
# Train Epoch: 10 [22400/50000 (45%)]	Loss: 1.493315
# Train Epoch: 10 [23040/50000 (46%)]	Loss: 1.302616
# Train Epoch: 10 [23680/50000 (47%)]	Loss: 1.369456
# Train Epoch: 10 [24320/50000 (49%)]	Loss: 1.260800
# Train Epoch: 10 [24960/50000 (50%)]	Loss: 1.516859
# Train Epoch: 10 [25600/50000 (51%)]	Loss: 1.428950
# Train Epoch: 10 [26240/50000 (52%)]	Loss: 1.494910
# Train Epoch: 10 [26880/50000 (54%)]	Loss: 1.450775
# Train Epoch: 10 [27520/50000 (55%)]	Loss: 1.555078
# Train Epoch: 10 [28160/50000 (56%)]	Loss: 1.540507
# Train Epoch: 10 [28800/50000 (58%)]	Loss: 1.490270
# Train Epoch: 10 [29440/50000 (59%)]	Loss: 1.418979
# Train Epoch: 10 [30080/50000 (60%)]	Loss: 1.462800
# Train Epoch: 10 [30720/50000 (61%)]	Loss: 1.637109
# Train Epoch: 10 [31360/50000 (63%)]	Loss: 1.406518
# Train Epoch: 10 [32000/50000 (64%)]	Loss: 1.282216
# Train Epoch: 10 [32640/50000 (65%)]	Loss: 1.491371
# Train Epoch: 10 [33280/50000 (66%)]	Loss: 1.514876
# Train Epoch: 10 [33920/50000 (68%)]	Loss: 1.619398
# Train Epoch: 10 [34560/50000 (69%)]	Loss: 1.299982
# Train Epoch: 10 [35200/50000 (70%)]	Loss: 1.488438
# Train Epoch: 10 [35840/50000 (72%)]	Loss: 1.546301
# Train Epoch: 10 [36480/50000 (73%)]	Loss: 1.633071
# Train Epoch: 10 [37120/50000 (74%)]	Loss: 1.540465
# Train Epoch: 10 [37760/50000 (75%)]	Loss: 1.559511
# Train Epoch: 10 [38400/50000 (77%)]	Loss: 1.671964
# Train Epoch: 10 [39040/50000 (78%)]	Loss: 1.560718
# Train Epoch: 10 [39680/50000 (79%)]	Loss: 1.464242
# Train Epoch: 10 [40320/50000 (81%)]	Loss: 1.402740
# Train Epoch: 10 [40960/50000 (82%)]	Loss: 1.283643
# Train Epoch: 10 [41600/50000 (83%)]	Loss: 1.328835
# Train Epoch: 10 [42240/50000 (84%)]	Loss: 1.308524
# Train Epoch: 10 [42880/50000 (86%)]	Loss: 1.429154
# Train Epoch: 10 [43520/50000 (87%)]	Loss: 1.547354
# Train Epoch: 10 [44160/50000 (88%)]	Loss: 1.533246
# Train Epoch: 10 [44800/50000 (90%)]	Loss: 1.501891
# Train Epoch: 10 [45440/50000 (91%)]	Loss: 1.591321
# Train Epoch: 10 [46080/50000 (92%)]	Loss: 1.577536
# Train Epoch: 10 [46720/50000 (93%)]	Loss: 1.591957
# Train Epoch: 10 [47360/50000 (95%)]	Loss: 1.315928
# Train Epoch: 10 [48000/50000 (96%)]	Loss: 1.489565
# Train Epoch: 10 [48640/50000 (97%)]	Loss: 1.377075
# Train Epoch: 10 [49280/50000 (98%)]	Loss: 1.352133
# Train Epoch: 10 [49920/50000 (100%)]	Loss: 1.329844
#
# Test set: Avg. loss: 2.0847, Accuracy: 3443/10000 (34.4%)
#
#
# --- saving model for best accuracy ---
# --- saving finished ---
#
# Train Epoch: 11 [0/50000 (0%)]	Loss: 1.667664
# Train Epoch: 11 [640/50000 (1%)]	Loss: 1.505072
# Train Epoch: 11 [1280/50000 (3%)]	Loss: 1.584457
# Train Epoch: 11 [1920/50000 (4%)]	Loss: 1.366933
# Train Epoch: 11 [2560/50000 (5%)]	Loss: 1.375686
# Train Epoch: 11 [3200/50000 (6%)]	Loss: 1.480985
# Train Epoch: 11 [3840/50000 (8%)]	Loss: 1.302497
# Train Epoch: 11 [4480/50000 (9%)]	Loss: 1.452942
# Train Epoch: 11 [5120/50000 (10%)]	Loss: 1.382594
# Train Epoch: 11 [5760/50000 (12%)]	Loss: 1.437152
# Train Epoch: 11 [6400/50000 (13%)]	Loss: 1.426425
# Train Epoch: 11 [7040/50000 (14%)]	Loss: 1.341903
# Train Epoch: 11 [7680/50000 (15%)]	Loss: 1.310585
# Train Epoch: 11 [8320/50000 (17%)]	Loss: 1.413080
# Train Epoch: 11 [8960/50000 (18%)]	Loss: 1.374079
# Train Epoch: 11 [9600/50000 (19%)]	Loss: 1.394612
# Train Epoch: 11 [10240/50000 (20%)]	Loss: 1.412763
# Train Epoch: 11 [10880/50000 (22%)]	Loss: 1.352456
# Train Epoch: 11 [11520/50000 (23%)]	Loss: 1.566055
# Train Epoch: 11 [12160/50000 (24%)]	Loss: 1.488497
# Train Epoch: 11 [12800/50000 (26%)]	Loss: 1.473686
# Train Epoch: 11 [13440/50000 (27%)]	Loss: 1.349707
# Train Epoch: 11 [14080/50000 (28%)]	Loss: 1.396559
# Train Epoch: 11 [14720/50000 (29%)]	Loss: 1.294058
# Train Epoch: 11 [15360/50000 (31%)]	Loss: 1.387646
# Train Epoch: 11 [16000/50000 (32%)]	Loss: 1.677302
# Train Epoch: 11 [16640/50000 (33%)]	Loss: 1.479790
# Train Epoch: 11 [17280/50000 (35%)]	Loss: 1.403984
# Train Epoch: 11 [17920/50000 (36%)]	Loss: 1.472461
# Train Epoch: 11 [18560/50000 (37%)]	Loss: 1.484681
# Train Epoch: 11 [19200/50000 (38%)]	Loss: 1.331121
# Train Epoch: 11 [19840/50000 (40%)]	Loss: 1.350919
# Train Epoch: 11 [20480/50000 (41%)]	Loss: 1.470766
# Train Epoch: 11 [21120/50000 (42%)]	Loss: 1.488943
# Train Epoch: 11 [21760/50000 (43%)]	Loss: 1.385198
# Train Epoch: 11 [22400/50000 (45%)]	Loss: 1.618999
# Train Epoch: 11 [23040/50000 (46%)]	Loss: 1.283667
# Train Epoch: 11 [23680/50000 (47%)]	Loss: 1.478875
# Train Epoch: 11 [24320/50000 (49%)]	Loss: 1.443753
# Train Epoch: 11 [24960/50000 (50%)]	Loss: 1.481223
# Train Epoch: 11 [25600/50000 (51%)]	Loss: 1.399755
# Train Epoch: 11 [26240/50000 (52%)]	Loss: 1.393827
# Train Epoch: 11 [26880/50000 (54%)]	Loss: 1.500715
# Train Epoch: 11 [27520/50000 (55%)]	Loss: 1.582910
# Train Epoch: 11 [28160/50000 (56%)]	Loss: 1.342604
# Train Epoch: 11 [28800/50000 (58%)]	Loss: 1.384313
# Train Epoch: 11 [29440/50000 (59%)]	Loss: 1.123542
# Train Epoch: 11 [30080/50000 (60%)]	Loss: 1.442492
# Train Epoch: 11 [30720/50000 (61%)]	Loss: 1.512088
# Train Epoch: 11 [31360/50000 (63%)]	Loss: 1.593810
# Train Epoch: 11 [32000/50000 (64%)]	Loss: 1.562938
# Train Epoch: 11 [32640/50000 (65%)]	Loss: 1.415793
# Train Epoch: 11 [33280/50000 (66%)]	Loss: 1.505365
# Train Epoch: 11 [33920/50000 (68%)]	Loss: 1.426501
# Train Epoch: 11 [34560/50000 (69%)]	Loss: 1.448204
# Train Epoch: 11 [35200/50000 (70%)]	Loss: 1.407253
# Train Epoch: 11 [35840/50000 (72%)]	Loss: 1.463053
# Train Epoch: 11 [36480/50000 (73%)]	Loss: 1.495396
# Train Epoch: 11 [37120/50000 (74%)]	Loss: 1.294234
# Train Epoch: 11 [37760/50000 (75%)]	Loss: 1.573329
# Train Epoch: 11 [38400/50000 (77%)]	Loss: 1.517349
# Train Epoch: 11 [39040/50000 (78%)]	Loss: 1.346321
# Train Epoch: 11 [39680/50000 (79%)]	Loss: 1.539003
# Train Epoch: 11 [40320/50000 (81%)]	Loss: 1.395591
# Train Epoch: 11 [40960/50000 (82%)]	Loss: 1.309112
# Train Epoch: 11 [41600/50000 (83%)]	Loss: 1.330568
# Train Epoch: 11 [42240/50000 (84%)]	Loss: 1.453694
# Train Epoch: 11 [42880/50000 (86%)]	Loss: 1.641188
# Train Epoch: 11 [43520/50000 (87%)]	Loss: 1.333512
# Train Epoch: 11 [44160/50000 (88%)]	Loss: 1.419868
# Train Epoch: 11 [44800/50000 (90%)]	Loss: 1.430787
# Train Epoch: 11 [45440/50000 (91%)]	Loss: 1.427918
# Train Epoch: 11 [46080/50000 (92%)]	Loss: 1.388575
# Train Epoch: 11 [46720/50000 (93%)]	Loss: 1.403450
# Train Epoch: 11 [47360/50000 (95%)]	Loss: 1.402112
# Train Epoch: 11 [48000/50000 (96%)]	Loss: 1.232531
# Train Epoch: 11 [48640/50000 (97%)]	Loss: 1.492051
# Train Epoch: 11 [49280/50000 (98%)]	Loss: 1.546605
# Train Epoch: 11 [49920/50000 (100%)]	Loss: 1.746967
#
# Test set: Avg. loss: 2.0440, Accuracy: 3670/10000 (36.7%)
#
#
# --- saving model for best accuracy ---
# --- saving finished ---
#
# Train Epoch: 12 [0/50000 (0%)]	Loss: 1.436803
# Train Epoch: 12 [640/50000 (1%)]	Loss: 1.368809
# Train Epoch: 12 [1280/50000 (3%)]	Loss: 1.276520
# Train Epoch: 12 [1920/50000 (4%)]	Loss: 1.346080
# Train Epoch: 12 [2560/50000 (5%)]	Loss: 1.494777
# Train Epoch: 12 [3200/50000 (6%)]	Loss: 1.310395
# Train Epoch: 12 [3840/50000 (8%)]	Loss: 1.513371
# Train Epoch: 12 [4480/50000 (9%)]	Loss: 1.284166
# Train Epoch: 12 [5120/50000 (10%)]	Loss: 1.282572
# Train Epoch: 12 [5760/50000 (12%)]	Loss: 1.343334
# Train Epoch: 12 [6400/50000 (13%)]	Loss: 1.321582
# Train Epoch: 12 [7040/50000 (14%)]	Loss: 1.348298
# Train Epoch: 12 [7680/50000 (15%)]	Loss: 1.348945
# Train Epoch: 12 [8320/50000 (17%)]	Loss: 1.387085
# Train Epoch: 12 [8960/50000 (18%)]	Loss: 1.269747
# Train Epoch: 12 [9600/50000 (19%)]	Loss: 1.314067
# Train Epoch: 12 [10240/50000 (20%)]	Loss: 1.419645
# Train Epoch: 12 [10880/50000 (22%)]	Loss: 1.580692
# Train Epoch: 12 [11520/50000 (23%)]	Loss: 1.409764
# Train Epoch: 12 [12160/50000 (24%)]	Loss: 1.513328
# Train Epoch: 12 [12800/50000 (26%)]	Loss: 1.566238
# Train Epoch: 12 [13440/50000 (27%)]	Loss: 1.471343
# Train Epoch: 12 [14080/50000 (28%)]	Loss: 1.513811
# Train Epoch: 12 [14720/50000 (29%)]	Loss: 1.525410
# Train Epoch: 12 [15360/50000 (31%)]	Loss: 1.391068
# Train Epoch: 12 [16000/50000 (32%)]	Loss: 1.406882
# Train Epoch: 12 [16640/50000 (33%)]	Loss: 1.476548
# Train Epoch: 12 [17280/50000 (35%)]	Loss: 1.514414
# Train Epoch: 12 [17920/50000 (36%)]	Loss: 1.472120
# Train Epoch: 12 [18560/50000 (37%)]	Loss: 1.546419
# Train Epoch: 12 [19200/50000 (38%)]	Loss: 1.158974
# Train Epoch: 12 [19840/50000 (40%)]	Loss: 1.581278
# Train Epoch: 12 [20480/50000 (41%)]	Loss: 1.561194
# Train Epoch: 12 [21120/50000 (42%)]	Loss: 1.402923
# Train Epoch: 12 [21760/50000 (43%)]	Loss: 1.567475
# Train Epoch: 12 [22400/50000 (45%)]	Loss: 1.419575
# Train Epoch: 12 [23040/50000 (46%)]	Loss: 1.478674
# Train Epoch: 12 [23680/50000 (47%)]	Loss: 1.607439
# Train Epoch: 12 [24320/50000 (49%)]	Loss: 1.488504
# Train Epoch: 12 [24960/50000 (50%)]	Loss: 1.524675
# Train Epoch: 12 [25600/50000 (51%)]	Loss: 1.385302
# Train Epoch: 12 [26240/50000 (52%)]	Loss: 1.490246
# Train Epoch: 12 [26880/50000 (54%)]	Loss: 1.372256
# Train Epoch: 12 [27520/50000 (55%)]	Loss: 1.383210
# Train Epoch: 12 [28160/50000 (56%)]	Loss: 1.215247
# Train Epoch: 12 [28800/50000 (58%)]	Loss: 1.625533
# Train Epoch: 12 [29440/50000 (59%)]	Loss: 1.743533
# Train Epoch: 12 [30080/50000 (60%)]	Loss: 1.561713
# Train Epoch: 12 [30720/50000 (61%)]	Loss: 1.560859
# Train Epoch: 12 [31360/50000 (63%)]	Loss: 1.433290
# Train Epoch: 12 [32000/50000 (64%)]	Loss: 1.420313
# Train Epoch: 12 [32640/50000 (65%)]	Loss: 1.475741
# Train Epoch: 12 [33280/50000 (66%)]	Loss: 1.418248
# Train Epoch: 12 [33920/50000 (68%)]	Loss: 1.437836
# Train Epoch: 12 [34560/50000 (69%)]	Loss: 1.281982
# Train Epoch: 12 [35200/50000 (70%)]	Loss: 1.596311
# Train Epoch: 12 [35840/50000 (72%)]	Loss: 1.177335
# Train Epoch: 12 [36480/50000 (73%)]	Loss: 1.488009
# Train Epoch: 12 [37120/50000 (74%)]	Loss: 1.532390
# Train Epoch: 12 [37760/50000 (75%)]	Loss: 1.556710
# ...
# Train Epoch: 197 [10880/50000 (22%)]	Loss: 0.852813
# Train Epoch: 197 [11520/50000 (23%)]	Loss: 0.838463
# Train Epoch: 197 [12160/50000 (24%)]	Loss: 0.879984
# Train Epoch: 197 [12800/50000 (26%)]	Loss: 0.846015
# Train Epoch: 197 [13440/50000 (27%)]	Loss: 0.888156
# Train Epoch: 197 [14080/50000 (28%)]	Loss: 0.882535
# Train Epoch: 197 [14720/50000 (29%)]	Loss: 0.875491
# Train Epoch: 197 [15360/50000 (31%)]	Loss: 0.889129
# Train Epoch: 197 [16000/50000 (32%)]	Loss: 0.782316
# Train Epoch: 197 [16640/50000 (33%)]	Loss: 0.749416
# Train Epoch: 197 [17280/50000 (35%)]	Loss: 0.905602
# Train Epoch: 197 [17920/50000 (36%)]	Loss: 1.172099
# Train Epoch: 197 [18560/50000 (37%)]	Loss: 0.957462
# Train Epoch: 197 [19200/50000 (38%)]	Loss: 1.019547
# Train Epoch: 197 [19840/50000 (40%)]	Loss: 0.773543
# Train Epoch: 197 [20480/50000 (41%)]	Loss: 1.199846
# Train Epoch: 197 [21120/50000 (42%)]	Loss: 0.987579
# Train Epoch: 197 [21760/50000 (43%)]	Loss: 0.913545
# Train Epoch: 197 [22400/50000 (45%)]	Loss: 1.029922
# Train Epoch: 197 [23040/50000 (46%)]	Loss: 1.000807
# Train Epoch: 197 [23680/50000 (47%)]	Loss: 1.176299
# Train Epoch: 197 [24320/50000 (49%)]	Loss: 0.826915
# Train Epoch: 197 [24960/50000 (50%)]	Loss: 0.837851
# Train Epoch: 197 [25600/50000 (51%)]	Loss: 0.978280
# Train Epoch: 197 [26240/50000 (52%)]	Loss: 1.014969
# Train Epoch: 197 [26880/50000 (54%)]	Loss: 0.971481
# Train Epoch: 197 [27520/50000 (55%)]	Loss: 1.015174
# Train Epoch: 197 [28160/50000 (56%)]	Loss: 1.027893
# Train Epoch: 197 [28800/50000 (58%)]	Loss: 0.811348
# Train Epoch: 197 [29440/50000 (59%)]	Loss: 0.971237
# Train Epoch: 197 [30080/50000 (60%)]	Loss: 1.061689
# Train Epoch: 197 [30720/50000 (61%)]	Loss: 0.974768
# Train Epoch: 197 [31360/50000 (63%)]	Loss: 0.862832
# Train Epoch: 197 [32000/50000 (64%)]	Loss: 0.797821
# Train Epoch: 197 [32640/50000 (65%)]	Loss: 0.827173
# Train Epoch: 197 [33280/50000 (66%)]	Loss: 1.074388
# Train Epoch: 197 [33920/50000 (68%)]	Loss: 1.146320
# Train Epoch: 197 [34560/50000 (69%)]	Loss: 0.830955
# Train Epoch: 197 [35200/50000 (70%)]	Loss: 0.925920
# Train Epoch: 197 [35840/50000 (72%)]	Loss: 1.095670
# Train Epoch: 197 [36480/50000 (73%)]	Loss: 0.859832
# Train Epoch: 197 [37120/50000 (74%)]	Loss: 0.910526
# Train Epoch: 197 [37760/50000 (75%)]	Loss: 0.933833
# Train Epoch: 197 [38400/50000 (77%)]	Loss: 0.959799
# Train Epoch: 197 [39040/50000 (78%)]	Loss: 0.998827
# Train Epoch: 197 [39680/50000 (79%)]	Loss: 0.949894
# Train Epoch: 197 [40320/50000 (81%)]	Loss: 1.000426
# Train Epoch: 197 [40960/50000 (82%)]	Loss: 0.847750
# Train Epoch: 197 [41600/50000 (83%)]	Loss: 0.959127
# Train Epoch: 197 [42240/50000 (84%)]	Loss: 0.816088
# Train Epoch: 197 [42880/50000 (86%)]	Loss: 0.876011
# Train Epoch: 197 [43520/50000 (87%)]	Loss: 0.956501
# Train Epoch: 197 [44160/50000 (88%)]	Loss: 1.144766
# Train Epoch: 197 [44800/50000 (90%)]	Loss: 0.982342
# Train Epoch: 197 [45440/50000 (91%)]	Loss: 0.867587
# Train Epoch: 197 [46080/50000 (92%)]	Loss: 0.937112
# Train Epoch: 197 [46720/50000 (93%)]	Loss: 0.945177
# Train Epoch: 197 [47360/50000 (95%)]	Loss: 1.048469
# Train Epoch: 197 [48000/50000 (96%)]	Loss: 0.952842
# Train Epoch: 197 [48640/50000 (97%)]	Loss: 0.968839
# Train Epoch: 197 [49280/50000 (98%)]	Loss: 1.112140
# Train Epoch: 197 [49920/50000 (100%)]	Loss: 0.929256
#
# Test set: Avg. loss: 3.3799, Accuracy: 3390/10000 (33.9%)
#
#
# --- saving model for best accuracy ---
# --- saving finished ---
#
# Train Epoch: 198 [0/50000 (0%)]	Loss: 1.037461
# Train Epoch: 198 [640/50000 (1%)]	Loss: 0.949609
# Train Epoch: 198 [1280/50000 (3%)]	Loss: 0.975671
# Train Epoch: 198 [1920/50000 (4%)]	Loss: 0.867509
# Train Epoch: 198 [2560/50000 (5%)]	Loss: 1.038253
# Train Epoch: 198 [3200/50000 (6%)]	Loss: 0.938348
# Train Epoch: 198 [3840/50000 (8%)]	Loss: 0.874958
# Train Epoch: 198 [4480/50000 (9%)]	Loss: 1.030912
# Train Epoch: 198 [5120/50000 (10%)]	Loss: 0.883102
# Train Epoch: 198 [5760/50000 (12%)]	Loss: 0.858479
# Train Epoch: 198 [6400/50000 (13%)]	Loss: 0.776284
# Train Epoch: 198 [7040/50000 (14%)]	Loss: 1.044573
# Train Epoch: 198 [7680/50000 (15%)]	Loss: 0.896064
# Train Epoch: 198 [8320/50000 (17%)]	Loss: 1.127821
# Train Epoch: 198 [8960/50000 (18%)]	Loss: 0.875054
# Train Epoch: 198 [9600/50000 (19%)]	Loss: 0.890081
# Train Epoch: 198 [10240/50000 (20%)]	Loss: 0.689516
# Train Epoch: 198 [10880/50000 (22%)]	Loss: 0.869748
# Train Epoch: 198 [11520/50000 (23%)]	Loss: 0.940052
# Train Epoch: 198 [12160/50000 (24%)]	Loss: 0.964761
# Train Epoch: 198 [12800/50000 (26%)]	Loss: 0.877446
# Train Epoch: 198 [13440/50000 (27%)]	Loss: 0.941383
# Train Epoch: 198 [14080/50000 (28%)]	Loss: 0.891407
# Train Epoch: 198 [14720/50000 (29%)]	Loss: 1.002692
# Train Epoch: 198 [15360/50000 (31%)]	Loss: 0.851988
# Train Epoch: 198 [16000/50000 (32%)]	Loss: 0.986268
# Train Epoch: 198 [16640/50000 (33%)]	Loss: 0.992676
# Train Epoch: 198 [17280/50000 (35%)]	Loss: 0.798523
# Train Epoch: 198 [17920/50000 (36%)]	Loss: 0.854577
# Train Epoch: 198 [18560/50000 (37%)]	Loss: 0.833706
# Train Epoch: 198 [19200/50000 (38%)]	Loss: 0.878647
# Train Epoch: 198 [19840/50000 (40%)]	Loss: 1.041146
# Train Epoch: 198 [20480/50000 (41%)]	Loss: 0.885082
# Train Epoch: 198 [21120/50000 (42%)]	Loss: 0.881167
# Train Epoch: 198 [21760/50000 (43%)]	Loss: 0.929161
# Train Epoch: 198 [22400/50000 (45%)]	Loss: 0.751853
# Train Epoch: 198 [23040/50000 (46%)]	Loss: 1.071455
# Train Epoch: 198 [23680/50000 (47%)]	Loss: 0.800942
# Train Epoch: 198 [24320/50000 (49%)]	Loss: 1.037755
# Train Epoch: 198 [24960/50000 (50%)]	Loss: 0.999356
# Train Epoch: 198 [25600/50000 (51%)]	Loss: 1.000560
# Train Epoch: 198 [26240/50000 (52%)]	Loss: 0.914737
# Train Epoch: 198 [26880/50000 (54%)]	Loss: 0.932149
# Train Epoch: 198 [27520/50000 (55%)]	Loss: 1.139928
# Train Epoch: 198 [28160/50000 (56%)]	Loss: 0.959425
# Train Epoch: 198 [28800/50000 (58%)]	Loss: 0.869647
# Train Epoch: 198 [29440/50000 (59%)]	Loss: 1.038713
# Train Epoch: 198 [30080/50000 (60%)]	Loss: 1.034790
# Train Epoch: 198 [30720/50000 (61%)]	Loss: 1.054819
# Train Epoch: 198 [31360/50000 (63%)]	Loss: 0.795658
# Train Epoch: 198 [32000/50000 (64%)]	Loss: 1.119261
# Train Epoch: 198 [32640/50000 (65%)]	Loss: 0.915419
# Train Epoch: 198 [33280/50000 (66%)]	Loss: 0.897501
# Train Epoch: 198 [33920/50000 (68%)]	Loss: 1.064770
# Train Epoch: 198 [34560/50000 (69%)]	Loss: 0.968202
# Train Epoch: 198 [35200/50000 (70%)]	Loss: 0.889177
# Train Epoch: 198 [35840/50000 (72%)]	Loss: 0.889060
# Train Epoch: 198 [36480/50000 (73%)]	Loss: 0.863053
# Train Epoch: 198 [37120/50000 (74%)]	Loss: 0.929833
# Train Epoch: 198 [37760/50000 (75%)]	Loss: 0.959198
# Train Epoch: 198 [38400/50000 (77%)]	Loss: 0.902425
# Train Epoch: 198 [39040/50000 (78%)]	Loss: 0.981753
# Train Epoch: 198 [39680/50000 (79%)]	Loss: 1.191695
# Train Epoch: 198 [40320/50000 (81%)]	Loss: 1.165430
# Train Epoch: 198 [40960/50000 (82%)]	Loss: 0.918763
# Train Epoch: 198 [41600/50000 (83%)]	Loss: 0.970716
# Train Epoch: 198 [42240/50000 (84%)]	Loss: 0.955304
# Train Epoch: 198 [42880/50000 (86%)]	Loss: 0.873511
# Train Epoch: 198 [43520/50000 (87%)]	Loss: 0.867211
# Train Epoch: 198 [44160/50000 (88%)]	Loss: 0.819796
# Train Epoch: 198 [44800/50000 (90%)]	Loss: 0.988141
# Train Epoch: 198 [45440/50000 (91%)]	Loss: 0.826983
# Train Epoch: 198 [46080/50000 (92%)]	Loss: 1.128255
# Train Epoch: 198 [46720/50000 (93%)]	Loss: 1.065905
# Train Epoch: 198 [47360/50000 (95%)]	Loss: 0.918700
# Train Epoch: 198 [48000/50000 (96%)]	Loss: 1.071381
# Train Epoch: 198 [48640/50000 (97%)]	Loss: 0.850278
# Train Epoch: 198 [49280/50000 (98%)]	Loss: 0.900848
# Train Epoch: 198 [49920/50000 (100%)]	Loss: 0.896821
#
# Test set: Avg. loss: 3.3958, Accuracy: 3402/10000 (34.0%)
#
#
# --- saving model for best accuracy ---
# --- saving finished ---
#
# Train Epoch: 199 [0/50000 (0%)]	Loss: 0.983006
# Train Epoch: 199 [640/50000 (1%)]	Loss: 0.902075
# Train Epoch: 199 [1280/50000 (3%)]	Loss: 0.892803
# Train Epoch: 199 [1920/50000 (4%)]	Loss: 0.868836
# Train Epoch: 199 [2560/50000 (5%)]	Loss: 0.987398
# Train Epoch: 199 [3200/50000 (6%)]	Loss: 0.981715
# Train Epoch: 199 [3840/50000 (8%)]	Loss: 0.967574
# Train Epoch: 199 [4480/50000 (9%)]	Loss: 1.078690
# Train Epoch: 199 [5120/50000 (10%)]	Loss: 0.944370
# Train Epoch: 199 [5760/50000 (12%)]	Loss: 0.932581
# Train Epoch: 199 [6400/50000 (13%)]	Loss: 0.907882
# Train Epoch: 199 [7040/50000 (14%)]	Loss: 0.901162
# Train Epoch: 199 [7680/50000 (15%)]	Loss: 1.091865
# Train Epoch: 199 [8320/50000 (17%)]	Loss: 0.830307
# Train Epoch: 199 [8960/50000 (18%)]	Loss: 1.136959
# Train Epoch: 199 [9600/50000 (19%)]	Loss: 0.993537
# Train Epoch: 199 [10240/50000 (20%)]	Loss: 0.890677
# Train Epoch: 199 [10880/50000 (22%)]	Loss: 0.694901
# Train Epoch: 199 [11520/50000 (23%)]	Loss: 0.826397
# Train Epoch: 199 [12160/50000 (24%)]	Loss: 0.874301
# Train Epoch: 199 [12800/50000 (26%)]	Loss: 0.885647
# Train Epoch: 199 [13440/50000 (27%)]	Loss: 0.870771
# Train Epoch: 199 [14080/50000 (28%)]	Loss: 0.894169
# Train Epoch: 199 [14720/50000 (29%)]	Loss: 1.052431
# Train Epoch: 199 [15360/50000 (31%)]	Loss: 0.951468
# Train Epoch: 199 [16000/50000 (32%)]	Loss: 0.934753
# Train Epoch: 199 [16640/50000 (33%)]	Loss: 0.827428
# Train Epoch: 199 [17280/50000 (35%)]	Loss: 0.896248
# Train Epoch: 199 [17920/50000 (36%)]	Loss: 0.856463
# Train Epoch: 199 [18560/50000 (37%)]	Loss: 0.819012
# Train Epoch: 199 [19200/50000 (38%)]	Loss: 0.944470
# Train Epoch: 199 [19840/50000 (40%)]	Loss: 1.078854
# Train Epoch: 199 [20480/50000 (41%)]	Loss: 1.012453
# Train Epoch: 199 [21120/50000 (42%)]	Loss: 0.959866
# Train Epoch: 199 [21760/50000 (43%)]	Loss: 0.946572
# Train Epoch: 199 [22400/50000 (45%)]	Loss: 0.966592
# Train Epoch: 199 [23040/50000 (46%)]	Loss: 0.975398
# Train Epoch: 199 [23680/50000 (47%)]	Loss: 0.767134
# Train Epoch: 199 [24320/50000 (49%)]	Loss: 0.933299
# Train Epoch: 199 [24960/50000 (50%)]	Loss: 0.822624
# Train Epoch: 199 [25600/50000 (51%)]	Loss: 0.877667
# Train Epoch: 199 [26240/50000 (52%)]	Loss: 0.882159
# Train Epoch: 199 [26880/50000 (54%)]	Loss: 0.851444
# Train Epoch: 199 [27520/50000 (55%)]	Loss: 0.955356
# Train Epoch: 199 [28160/50000 (56%)]	Loss: 0.997420
# Train Epoch: 199 [28800/50000 (58%)]	Loss: 0.988174
# Train Epoch: 199 [29440/50000 (59%)]	Loss: 1.064600
# Train Epoch: 199 [30080/50000 (60%)]	Loss: 1.066925
# Train Epoch: 199 [30720/50000 (61%)]	Loss: 1.004370
# Train Epoch: 199 [31360/50000 (63%)]	Loss: 0.856407
# Train Epoch: 199 [32000/50000 (64%)]	Loss: 0.903324
# Train Epoch: 199 [32640/50000 (65%)]	Loss: 0.882099
# Train Epoch: 199 [33280/50000 (66%)]	Loss: 0.825546
# Train Epoch: 199 [33920/50000 (68%)]	Loss: 0.912416
# Train Epoch: 199 [34560/50000 (69%)]	Loss: 0.875305
# Train Epoch: 199 [35200/50000 (70%)]	Loss: 0.789035
# Train Epoch: 199 [35840/50000 (72%)]	Loss: 0.892065
# Train Epoch: 199 [36480/50000 (73%)]	Loss: 0.904203
# Train Epoch: 199 [37120/50000 (74%)]	Loss: 0.917236
# Train Epoch: 199 [37760/50000 (75%)]	Loss: 1.012926
# Train Epoch: 199 [38400/50000 (77%)]	Loss: 1.030774
# Train Epoch: 199 [39040/50000 (78%)]	Loss: 0.879022
# Train Epoch: 199 [39680/50000 (79%)]	Loss: 0.839449
# Train Epoch: 199 [40320/50000 (81%)]	Loss: 0.895697
# Train Epoch: 199 [40960/50000 (82%)]	Loss: 1.019242
# Train Epoch: 199 [41600/50000 (83%)]	Loss: 1.086145
# Train Epoch: 199 [42240/50000 (84%)]	Loss: 1.131371
# Train Epoch: 199 [42880/50000 (86%)]	Loss: 1.230847
# Train Epoch: 199 [43520/50000 (87%)]	Loss: 0.973098
# Train Epoch: 199 [44160/50000 (88%)]	Loss: 0.833124
# Train Epoch: 199 [44800/50000 (90%)]	Loss: 1.088635
# Train Epoch: 199 [45440/50000 (91%)]	Loss: 1.028723
# Train Epoch: 199 [46080/50000 (92%)]	Loss: 0.956583
# Train Epoch: 199 [46720/50000 (93%)]	Loss: 1.019113
# Train Epoch: 199 [47360/50000 (95%)]	Loss: 1.075180
# Train Epoch: 199 [48000/50000 (96%)]	Loss: 0.976358
# Train Epoch: 199 [48640/50000 (97%)]	Loss: 1.190737
# Train Epoch: 199 [49280/50000 (98%)]	Loss: 1.075153
# Train Epoch: 199 [49920/50000 (100%)]	Loss: 0.845264
#
# Test set: Avg. loss: 3.4814, Accuracy: 3376/10000 (33.8%)
#
#
# --- saving model for best accuracy ---
# --- saving finished ---
#
# Train Epoch: 200 [0/50000 (0%)]	Loss: 1.104843
# Train Epoch: 200 [640/50000 (1%)]	Loss: 0.899325
# Train Epoch: 200 [1280/50000 (3%)]	Loss: 0.975791
# Train Epoch: 200 [1920/50000 (4%)]	Loss: 0.967777
# Train Epoch: 200 [2560/50000 (5%)]	Loss: 0.812675
# Train Epoch: 200 [3200/50000 (6%)]	Loss: 0.946305
# Train Epoch: 200 [3840/50000 (8%)]	Loss: 0.947200
# Train Epoch: 200 [4480/50000 (9%)]	Loss: 0.958967
# Train Epoch: 200 [5120/50000 (10%)]	Loss: 0.849881
# Train Epoch: 200 [5760/50000 (12%)]	Loss: 0.925909
# Train Epoch: 200 [6400/50000 (13%)]	Loss: 0.971777
# Train Epoch: 200 [7040/50000 (14%)]	Loss: 0.995683
# Train Epoch: 200 [7680/50000 (15%)]	Loss: 0.961441
# Train Epoch: 200 [8320/50000 (17%)]	Loss: 0.875926
# Train Epoch: 200 [8960/50000 (18%)]	Loss: 0.945790
# Train Epoch: 200 [9600/50000 (19%)]	Loss: 0.784514
# Train Epoch: 200 [10240/50000 (20%)]	Loss: 0.666072
# Train Epoch: 200 [10880/50000 (22%)]	Loss: 1.055333
# Train Epoch: 200 [11520/50000 (23%)]	Loss: 0.953642
# Train Epoch: 200 [12160/50000 (24%)]	Loss: 0.891095
# Train Epoch: 200 [12800/50000 (26%)]	Loss: 0.860662
# Train Epoch: 200 [13440/50000 (27%)]	Loss: 0.915968
# Train Epoch: 200 [14080/50000 (28%)]	Loss: 1.008197
# Train Epoch: 200 [14720/50000 (29%)]	Loss: 0.886376
# Train Epoch: 200 [15360/50000 (31%)]	Loss: 0.782904
# Train Epoch: 200 [16000/50000 (32%)]	Loss: 1.013561
# Train Epoch: 200 [16640/50000 (33%)]	Loss: 1.012434
# Train Epoch: 200 [17280/50000 (35%)]	Loss: 0.944250
# Train Epoch: 200 [17920/50000 (36%)]	Loss: 0.922496
# Train Epoch: 200 [18560/50000 (37%)]	Loss: 0.832817
# Train Epoch: 200 [19200/50000 (38%)]	Loss: 0.954577
# Train Epoch: 200 [19840/50000 (40%)]	Loss: 0.891809
# Train Epoch: 200 [20480/50000 (41%)]	Loss: 1.028170
# Train Epoch: 200 [21120/50000 (42%)]	Loss: 0.892005
# Train Epoch: 200 [21760/50000 (43%)]	Loss: 0.912828
# Train Epoch: 200 [22400/50000 (45%)]	Loss: 0.886701
# Train Epoch: 200 [23040/50000 (46%)]	Loss: 0.952567
# Train Epoch: 200 [23680/50000 (47%)]	Loss: 1.077117
# Train Epoch: 200 [24320/50000 (49%)]	Loss: 0.848442
# Train Epoch: 200 [24960/50000 (50%)]	Loss: 1.095070
# Train Epoch: 200 [25600/50000 (51%)]	Loss: 1.161478
# Train Epoch: 200 [26240/50000 (52%)]	Loss: 1.061111
# Train Epoch: 200 [26880/50000 (54%)]	Loss: 1.050682
# Train Epoch: 200 [27520/50000 (55%)]	Loss: 1.001556
# Train Epoch: 200 [28160/50000 (56%)]	Loss: 0.901797
# Train Epoch: 200 [28800/50000 (58%)]	Loss: 1.028347
# Train Epoch: 200 [29440/50000 (59%)]	Loss: 0.914676
# Train Epoch: 200 [30080/50000 (60%)]	Loss: 0.948453
# Train Epoch: 200 [30720/50000 (61%)]	Loss: 1.063800
# Train Epoch: 200 [31360/50000 (63%)]	Loss: 1.067022
# Train Epoch: 200 [32000/50000 (64%)]	Loss: 0.826558
# Train Epoch: 200 [32640/50000 (65%)]	Loss: 1.099980
# Train Epoch: 200 [33280/50000 (66%)]	Loss: 0.976711
# Train Epoch: 200 [33920/50000 (68%)]	Loss: 0.890235
# Train Epoch: 200 [34560/50000 (69%)]	Loss: 1.040015
# Train Epoch: 200 [35200/50000 (70%)]	Loss: 0.828473
# Train Epoch: 200 [35840/50000 (72%)]	Loss: 0.895903
# Train Epoch: 200 [36480/50000 (73%)]	Loss: 1.042795
# Train Epoch: 200 [37120/50000 (74%)]	Loss: 1.178267
# Train Epoch: 200 [37760/50000 (75%)]	Loss: 1.061034
# Train Epoch: 200 [38400/50000 (77%)]	Loss: 0.819598
# Train Epoch: 200 [39040/50000 (78%)]	Loss: 0.897294
# Train Epoch: 200 [39680/50000 (79%)]	Loss: 0.907931
# Train Epoch: 200 [40320/50000 (81%)]	Loss: 0.925672
# Train Epoch: 200 [40960/50000 (82%)]	Loss: 0.924630
# Train Epoch: 200 [41600/50000 (83%)]	Loss: 0.807696
# Train Epoch: 200 [42240/50000 (84%)]	Loss: 0.884128
# Train Epoch: 200 [42880/50000 (86%)]	Loss: 0.862967
# Train Epoch: 200 [43520/50000 (87%)]	Loss: 0.924284
# Train Epoch: 200 [44160/50000 (88%)]	Loss: 1.122364
# Train Epoch: 200 [44800/50000 (90%)]	Loss: 1.019165
# Train Epoch: 200 [45440/50000 (91%)]	Loss: 1.060701
# Train Epoch: 200 [46080/50000 (92%)]	Loss: 1.050472
# Train Epoch: 200 [46720/50000 (93%)]	Loss: 0.917592
# Train Epoch: 200 [47360/50000 (95%)]	Loss: 0.875061
# Train Epoch: 200 [48000/50000 (96%)]	Loss: 1.022747
# Train Epoch: 200 [48640/50000 (97%)]	Loss: 0.973867
# Train Epoch: 200 [49280/50000 (98%)]	Loss: 0.779129
# Train Epoch: 200 [49920/50000 (100%)]	Loss: 0.975410
#
# Test set: Avg. loss: 3.3849, Accuracy: 3447/10000 (34.5%)
#
#
# --- saving model for best accuracy ---
# --- saving finished ---

# %%
## fig = plt.figure()
plt.plot(train_counter, train_losses, color='blue')
plt.scatter(test_counter, test_losses, color='red')
plt.legend(['Train Loss', 'Test Loss'], loc='upper right')
plt.xlabel('number of training examples seen')
plt.ylabel('negative log likelihood loss')
# Out:
# Text(0, 0.5, 'negative log likelihood loss')
